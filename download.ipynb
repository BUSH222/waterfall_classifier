# %%
import os
from dotenv import load_dotenv
import requests
import time

load_dotenv()

API_TOKEN = os.getenv("API_TOKEN")
header = {'Authorization': f'Token {API_TOKEN}'}
signalurl = "https://network.satnogs.org/api/observations/?waterfall_status=1&format=json"
nosignalurl = "https://network.satnogs.org/api/observations/?waterfall_status=0&format=json"
NUM_PAGES = 800*2

# %%
prepare_directores = True
if prepare_directores:
    os.makedirs("data", exist_ok=True)
    os.makedirs("data/with_signal", exist_ok=True)
    os.makedirs("data/without_signal", exist_ok=True)

# %%
link = signalurl

def download_waterfalls(url, folder, num_pages):
    link = url
    for i in range(num_pages - 1):
        response = requests.get(link, headers=header)
        if response.status_code == 429:
            print("Rate limit exceeded. Waiting...")
            time.sleep(60)
            response = requests.get(link, headers=header)

        observation_ids = [k['id'] for k in response.json()]
        waterfall_urls = [k['waterfall'] for k in response.json()]
        transmitter_modes = [k['transmitter_mode'] or 'UNKNWN' for k in response.json()]
        print(f"Page {i+1}: Downloading {len(waterfall_urls)} waterfalls")
        for obs_id, waterfall_url, transmitter_mode in zip(observation_ids, waterfall_urls, transmitter_modes):
            waterfall_data = requests.get(waterfall_url).content
            with open(f"{folder}/{obs_id}_{transmitter_mode}.png", "wb") as f:
                f.write(waterfall_data)
        link = response.links.get('next', {}).get('url', None)
        if link is None:
            break

# %%
if False:  # Change to True to download data
    download_waterfalls(signalurl, "data/with_signal", NUM_PAGES)
    download_waterfalls(nosignalurl, "data/without_signal", NUM_PAGES)

# %%
import cv2
import numpy as np
from pathlib import Path

def crop_waterfall(image_path, output_path=None,
                   black_threshold=40,
                   min_horizontal_fraction=0.7):
    image_path = Path(image_path)
    img = cv2.imread(str(image_path))
    if img is None:
        raise ValueError(f"Could not read image at {image_path}")

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    h, w = gray.shape
    is_black = gray < black_threshold
    x_probe = w // 4
    y_top = None
    for y in range(h):
        if is_black[y, x_probe]:
            y_top = y
            break
    if y_top is None:
        raise ValueError("Top border not found.")

    x_left = x_probe
    while x_left > 0 and is_black[y_top, x_left - 1]:
        x_left -= 1

    x_right = x_probe
    while x_right < w - 1 and is_black[y_top, x_right + 1]:
        x_right += 1

    span_width = x_right - x_left + 1
    y_bottom = None
    for y in range(h - 1, -1, -1):
        frac_black = is_black[y, x_left:x_right + 1].mean()
        if frac_black >= min_horizontal_fraction:
            y_bottom = y
            break
    if y_bottom is None:
        raise ValueError("Bottom border not found.")

    y0 = max(y_top + 1, 0)
    y1 = min(y_bottom, h - 1)
    x0 = max(x_left + 1, 0)
    x1 = min(x_right, w - 1)

    dimensions = (x1 - x0, y1 - y0)

    cropped = img[y0:y1, x0:x1]
    if cropped.size == 0:
        raise ValueError("Computed crop is empty; check thresholds.")

    if output_path is not None:
        output_path = Path(output_path)
        cv2.imwrite(str(output_path), cropped)

    return dimensions

# %%
import glob

if False:
    dimensions_with = []

    datadir_with = 'data/with_signal'
    datadir_without = 'data/without_signal'
    for filepath in glob.glob(os.path.join(datadir_with, '*.png')):
        dim = crop_waterfall(filepath, output_path=filepath)
        dimensions_with.append(dim)

    print(f"Processed {len(dimensions_with)} images with waterfalls.")

# %%
if False:
    dimensions_without = []

    datadir_with = 'data/with_signal'
    datadir_without = 'data/without_signal'
    for filepath in glob.glob(os.path.join(datadir_without, '*.png')):
        try:
            dim = crop_waterfall(filepath, output_path=filepath)
            dimensions_without.append(dim)
        except Exception as e:
            if str(e) == "Top border not found." or str(e) == "Bottom border not found." or str(e) == "Computed crop is empty; check thresholds.":
                # skip already processed img
                continue
            print(f"Error processing {filepath}: {e}")

    print(f"Processed {len(dimensions_without)} images without waterfalls.")

# %%
def grayscale(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    return gray

def downscale_in_half(img):
    height, width = img.shape[:2]
    new_dimensions = (width // 2, height // 2)
    downscaled = cv2.resize(img, new_dimensions, interpolation=cv2.INTER_AREA)
    return downscaled

def remove_rl_edges(img, edge_width=50):
    h, w = img.shape[:2]
    cropped = img[0:h, edge_width:w - edge_width]
    return cropped

def grayscale_downscale_normalize(im_path, output_path=None):
    img = cv2.imread(im_path)
    if img is None:
        raise ValueError("Input image is None")
    
    h, w = img.shape[:2]
    if h >= 1500 and w >= 600:
        # Large image, crop it down to 1500x600 relative to center
        center_y, center_x = h // 2, w // 2
        half_h, half_w = 1500 // 2, 600 // 2
        y0 = max(center_y - half_h, 0)
        y1 = min(center_y + half_h, h)
        x0 = max(center_x - half_w, 0)
        x1 = min(center_x + half_w, w)
        img = img[y0:y1, x0:x1]
    else:
        print(f"Image {im_path} too small ({w}x{h}), deleting.")
        if input_path == output_path:
            os.remove(im_path)
        return None
    gray = grayscale(img)
    downscaled = remove_rl_edges(downscale_in_half(gray))
    if output_path is not None:
        output_path = Path(output_path)
        cv2.imwrite(str(output_path), downscaled)
    return downscaled

# %%
if True:
    datadir_with = 'data/with_signal'
    datadir_without = 'data/without_signal'

    for filepath in glob.glob(os.path.join(datadir_with, '*.png')):
        try:
            grayscale_downscale_normalize(filepath, output_path=filepath)
        except Exception as e:
            print(f"Error processing {filepath}: {e}")
    print("Finished processing with-signal images.")

    for filepath in glob.glob(os.path.join(datadir_without, '*.png')):
        try:
            grayscale_downscale_normalize(filepath, output_path=filepath)
        except Exception as e:
            print(f"Error processing {filepath}: {e}")
    print("Finished processing without-signal images.")
# Out:
# Finished processing with-signal images.
# Image data/without_signal/12833378_FSK AX.100 Mode 5.png too small (2x1543), deleting.
# Error processing data/without_signal/12833378_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12789005_FM.png too small (1x1405), deleting.
# Error processing data/without_signal/12789005_FM.png: name 'input_path' is not defined
# Image data/without_signal/12802333_BPSK.png too small (4x1398), deleting.
# Error processing data/without_signal/12802333_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12845138_FSK AX.100 Mode 5.png too small (4x843), deleting.
# Error processing data/without_signal/12845138_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12775189_SSTV.png too small (4x1511), deleting.
# Error processing data/without_signal/12775189_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12860964_BPSK.png too small (1x138), deleting.
# Error processing data/without_signal/12860964_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12898200_BPSK.png too small (1x1467), deleting.
# Error processing data/without_signal/12898200_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12980085_BPSK.png too small (4x1512), deleting.
# Error processing data/without_signal/12980085_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/13011850_FM.png too small (2x1515), deleting.
# Error processing data/without_signal/13011850_FM.png: name 'input_path' is not defined
# Image data/without_signal/12834085_MSK AX.100 Mode 5.png too small (1x1530), deleting.
# Error processing data/without_signal/12834085_MSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/13012875_CW.png too small (1x1397), deleting.
# Error processing data/without_signal/13012875_CW.png: name 'input_path' is not defined
# Image data/without_signal/12933719_FM.png too small (2x1462), deleting.
# Error processing data/without_signal/12933719_FM.png: name 'input_path' is not defined
# Image data/without_signal/13009222_USB.png too small (9x1504), deleting.
# Error processing data/without_signal/13009222_USB.png: name 'input_path' is not defined
# Image data/without_signal/12802316_GFSK.png too small (8x1534), deleting.
# Error processing data/without_signal/12802316_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12908376_FM.png too small (3x1515), deleting.
# Error processing data/without_signal/12908376_FM.png: name 'input_path' is not defined
# Image data/without_signal/12998731_CW.png too small (2x1526), deleting.
# Error processing data/without_signal/12998731_CW.png: name 'input_path' is not defined
# Image data/without_signal/12962414_CW.png too small (1x1394), deleting.
# Error processing data/without_signal/12962414_CW.png: name 'input_path' is not defined
# Image data/without_signal/13009809_CW.png too small (2x1534), deleting.
# Error processing data/without_signal/13009809_CW.png: name 'input_path' is not defined
# Image data/without_signal/12834910_GMSK.png too small (1x1497), deleting.
# Error processing data/without_signal/12834910_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12818648_MSK AX.100 Mode 5.png too small (1x1537), deleting.
# Error processing data/without_signal/12818648_MSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12777876_LRPT.png too small (3x1505), deleting.
# Error processing data/without_signal/12777876_LRPT.png: name 'input_path' is not defined
# Image data/without_signal/12948968_GMSK.png too small (14x1543), deleting.
# Error processing data/without_signal/12948968_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12944689_FSK.png too small (2x1411), deleting.
# Error processing data/without_signal/12944689_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12907936_FSK AX.100 Mode 5.png too small (1x1508), deleting.
# Error processing data/without_signal/12907936_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12983235_FSK.png too small (2x1431), deleting.
# Error processing data/without_signal/12983235_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12829637_GMSK.png too small (346x1537), deleting.
# Error processing data/without_signal/12829637_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12832827_CW.png too small (2x1491), deleting.
# Error processing data/without_signal/12832827_CW.png: name 'input_path' is not defined
# Image data/without_signal/12805007_AFSK.png too small (4x1396), deleting.
# Error processing data/without_signal/12805007_AFSK.png: name 'input_path' is not defined
# Image data/without_signal/13014369_AFSK.png too small (26x1398), deleting.
# Error processing data/without_signal/13014369_AFSK.png: name 'input_path' is not defined
# Image data/without_signal/12944228_FM.png too small (1x1448), deleting.
# Error processing data/without_signal/12944228_FM.png: name 'input_path' is not defined
# Image data/without_signal/12913199_FM.png too small (2x1536), deleting.
# Error processing data/without_signal/12913199_FM.png: name 'input_path' is not defined
# Image data/without_signal/12843436_GMSK.png too small (1x1513), deleting.
# Error processing data/without_signal/12843436_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12944473_FSK.png too small (1x1443), deleting.
# Error processing data/without_signal/12944473_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12973226_FSK.png too small (2x1530), deleting.
# Error processing data/without_signal/12973226_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12858047_GMSK.png too small (1x6), deleting.
# Error processing data/without_signal/12858047_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12856665_GMSK.png too small (2x1444), deleting.
# Error processing data/without_signal/12856665_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12759055_BPSK.png too small (1x1500), deleting.
# Error processing data/without_signal/12759055_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12875592_CW.png too small (5x1417), deleting.
# Error processing data/without_signal/12875592_CW.png: name 'input_path' is not defined
# Image data/without_signal/12930038_CW.png too small (1x1489), deleting.
# Error processing data/without_signal/12930038_CW.png: name 'input_path' is not defined
# Image data/without_signal/12831478_DUV.png too small (2x1529), deleting.
# Error processing data/without_signal/12831478_DUV.png: name 'input_path' is not defined
# Image data/without_signal/12838889_CW.png too small (4x970), deleting.
# Error processing data/without_signal/12838889_CW.png: name 'input_path' is not defined
# Image data/without_signal/12809476_GMSK.png too small (15x1544), deleting.
# Error processing data/without_signal/12809476_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/13015411_SSTV.png too small (1x1537), deleting.
# Error processing data/without_signal/13015411_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12881299_FM.png too small (1x1514), deleting.
# Error processing data/without_signal/12881299_FM.png: name 'input_path' is not defined
# Image data/without_signal/12970918_GMSK.png too small (2x1526), deleting.
# Error processing data/without_signal/12970918_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12762535_BPSK.png too small (2x1537), deleting.
# Error processing data/without_signal/12762535_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12809537_GMSK.png too small (26x1543), deleting.
# Error processing data/without_signal/12809537_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12774308_BPSK.png too small (1x1278), deleting.
# Error processing data/without_signal/12774308_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12863088_GFSK.png too small (154x1537), deleting.
# Error processing data/without_signal/12863088_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12819730_GMSK.png too small (11x1542), deleting.
# Error processing data/without_signal/12819730_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12759178_GFSK.png too small (1x1520), deleting.
# Error processing data/without_signal/12759178_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12934490_FM.png too small (2x1544), deleting.
# Error processing data/without_signal/12934490_FM.png: name 'input_path' is not defined
# Image data/without_signal/12824711_SSTV.png too small (5x1531), deleting.
# Error processing data/without_signal/12824711_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12848817_FM.png too small (1x1534), deleting.
# Error processing data/without_signal/12848817_FM.png: name 'input_path' is not defined
# Image data/without_signal/12895673_DUV.png too small (1x1519), deleting.
# Error processing data/without_signal/12895673_DUV.png: name 'input_path' is not defined
# Image data/without_signal/12867687_FM.png too small (2x1509), deleting.
# Error processing data/without_signal/12867687_FM.png: name 'input_path' is not defined
# Image data/without_signal/12823818_BPSK.png too small (1x1479), deleting.
# Error processing data/without_signal/12823818_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12969343_MSK AX.100 Mode 5.png too small (3x1513), deleting.
# Error processing data/without_signal/12969343_MSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12926271_CW.png too small (1x1497), deleting.
# Error processing data/without_signal/12926271_CW.png: name 'input_path' is not defined
# Image data/without_signal/12778582_FSK AX.100 Mode 5.png too small (4x1533), deleting.
# Error processing data/without_signal/12778582_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12898359_DUV.png too small (2x1505), deleting.
# Error processing data/without_signal/12898359_DUV.png: name 'input_path' is not defined
# Image data/without_signal/12899001_FSK.png too small (1x1221), deleting.
# Error processing data/without_signal/12899001_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12877186_CW.png too small (1x1367), deleting.
# Error processing data/without_signal/12877186_CW.png: name 'input_path' is not defined
# Image data/without_signal/12939464_BPSK.png too small (5x1528), deleting.
# Error processing data/without_signal/12939464_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12827415_FM.png too small (1x1506), deleting.
# Error processing data/without_signal/12827415_FM.png: name 'input_path' is not defined
# Image data/without_signal/12943707_FSK.png too small (1x1424), deleting.
# Error processing data/without_signal/12943707_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12843271_FSK.png too small (12x1352), deleting.
# Error processing data/without_signal/12843271_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12850694_FM.png too small (1x1506), deleting.
# Error processing data/without_signal/12850694_FM.png: name 'input_path' is not defined
# Image data/without_signal/12826513_FM.png too small (4x18), deleting.
# Error processing data/without_signal/12826513_FM.png: name 'input_path' is not defined
# Image data/without_signal/12781570_CW.png too small (4x1533), deleting.
# Error processing data/without_signal/12781570_CW.png: name 'input_path' is not defined
# Image data/without_signal/12990513_CW.png too small (1x1507), deleting.
# Error processing data/without_signal/12990513_CW.png: name 'input_path' is not defined
# Image data/without_signal/12971646_CW.png too small (1x1495), deleting.
# Error processing data/without_signal/12971646_CW.png: name 'input_path' is not defined
# Image data/without_signal/12996143_CW.png too small (5x1536), deleting.
# Error processing data/without_signal/12996143_CW.png: name 'input_path' is not defined
# Image data/without_signal/13010860_FM.png too small (1x1509), deleting.
# Error processing data/without_signal/13010860_FM.png: name 'input_path' is not defined
# Image data/without_signal/12944127_FM.png too small (1x1489), deleting.
# Error processing data/without_signal/12944127_FM.png: name 'input_path' is not defined
# Image data/without_signal/12775438_FM.png too small (1x1452), deleting.
# Error processing data/without_signal/12775438_FM.png: name 'input_path' is not defined
# Image data/without_signal/12845717_MSK AX.100 Mode 5.png too small (6x1544), deleting.
# Error processing data/without_signal/12845717_MSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12921152_FSK.png too small (1x974), deleting.
# Error processing data/without_signal/12921152_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12796720_GMSK.png too small (12x1528), deleting.
# Error processing data/without_signal/12796720_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/13013733_CW.png too small (3x1495), deleting.
# Error processing data/without_signal/13013733_CW.png: name 'input_path' is not defined
# Image data/without_signal/12768024_BPSK.png too small (5x1532), deleting.
# Error processing data/without_signal/12768024_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12872740_GFSK.png too small (153x1537), deleting.
# Error processing data/without_signal/12872740_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12870087_GMSK.png too small (1x1295), deleting.
# Error processing data/without_signal/12870087_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12862632_SSTV.png too small (513x358), deleting.
# Error processing data/without_signal/12862632_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12779534_LoRa.png too small (2x1499), deleting.
# Error processing data/without_signal/12779534_LoRa.png: name 'input_path' is not defined
# Image data/without_signal/12901532_GFSK.png too small (1x2), deleting.
# Error processing data/without_signal/12901532_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12837740_FM.png too small (1x1425), deleting.
# Error processing data/without_signal/12837740_FM.png: name 'input_path' is not defined
# Image data/without_signal/12992076_FSK.png too small (8x1432), deleting.
# Error processing data/without_signal/12992076_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12950676_FM.png too small (1x1510), deleting.
# Error processing data/without_signal/12950676_FM.png: name 'input_path' is not defined
# Image data/without_signal/12823499_FSK AX.100 Mode 5.png too small (1x1449), deleting.
# Error processing data/without_signal/12823499_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12785234_FSK AX.100 Mode 5.png too small (2x1510), deleting.
# Error processing data/without_signal/12785234_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12892103_MSK AX.100 Mode 5.png too small (6x62), deleting.
# Error processing data/without_signal/12892103_MSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12920365_USB.png too small (1x1296), deleting.
# Error processing data/without_signal/12920365_USB.png: name 'input_path' is not defined
# Image data/without_signal/12845431_FSK AX.100 Mode 5.png too small (6x1543), deleting.
# Error processing data/without_signal/12845431_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12824534_BPSK.png too small (1x1472), deleting.
# Error processing data/without_signal/12824534_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12954365_GMSK.png too small (1x1352), deleting.
# Error processing data/without_signal/12954365_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12834736_GMSK.png too small (1x1543), deleting.
# Error processing data/without_signal/12834736_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12865833_BPSK.png too small (1x1519), deleting.
# Error processing data/without_signal/12865833_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12921893_GMSK.png too small (1x1463), deleting.
# Error processing data/without_signal/12921893_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/13014906_CW.png too small (1x1521), deleting.
# Error processing data/without_signal/13014906_CW.png: name 'input_path' is not defined
# Image data/without_signal/12849508_BPSK.png too small (43x910), deleting.
# Error processing data/without_signal/12849508_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12915880_CW.png too small (1x1465), deleting.
# Error processing data/without_signal/12915880_CW.png: name 'input_path' is not defined
# Image data/without_signal/12833948_FM.png too small (18x1543), deleting.
# Error processing data/without_signal/12833948_FM.png: name 'input_path' is not defined
# Image data/without_signal/12974044_GFSK.png too small (1x1286), deleting.
# Error processing data/without_signal/12974044_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12768032_FSK AX.100 Mode 5.png too small (1x1530), deleting.
# Error processing data/without_signal/12768032_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12945668_FSK AX.25 G3RUH.png too small (469x186), deleting.
# Error processing data/without_signal/12945668_FSK AX.25 G3RUH.png: name 'input_path' is not defined
# Image data/without_signal/12944752_FM.png too small (7x1384), deleting.
# Error processing data/without_signal/12944752_FM.png: name 'input_path' is not defined
# Image data/without_signal/12780169_FM.png too small (2x1535), deleting.
# Error processing data/without_signal/12780169_FM.png: name 'input_path' is not defined
# Image data/without_signal/12962994_GMSK USP.png too small (1x1353), deleting.
# Error processing data/without_signal/12962994_GMSK USP.png: name 'input_path' is not defined
# Image data/without_signal/12794300_AFSK.png too small (2x1533), deleting.
# Error processing data/without_signal/12794300_AFSK.png: name 'input_path' is not defined
# Image data/without_signal/12776067_GMSK.png too small (1x1469), deleting.
# Error processing data/without_signal/12776067_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12827006_CW.png too small (1x1512), deleting.
# Error processing data/without_signal/12827006_CW.png: name 'input_path' is not defined
# Image data/without_signal/13008608_BPSK.png too small (1x1458), deleting.
# Error processing data/without_signal/13008608_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12844760_GFSK.png too small (3x1504), deleting.
# Error processing data/without_signal/12844760_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12916415_FM.png too small (1x1508), deleting.
# Error processing data/without_signal/12916415_FM.png: name 'input_path' is not defined
# Image data/without_signal/12955454_GMSK.png too small (1x1528), deleting.
# Error processing data/without_signal/12955454_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12945314_FM.png too small (1x1435), deleting.
# Error processing data/without_signal/12945314_FM.png: name 'input_path' is not defined
# Image data/without_signal/12981375_GMSK.png too small (3x1508), deleting.
# Error processing data/without_signal/12981375_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12908505_MSK AX.100 Mode 5.png too small (617x11), deleting.
# Error processing data/without_signal/12908505_MSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12766249_FM.png too small (1x1514), deleting.
# Error processing data/without_signal/12766249_FM.png: name 'input_path' is not defined
# Image data/without_signal/12763104_FM.png too small (1x1092), deleting.
# Error processing data/without_signal/12763104_FM.png: name 'input_path' is not defined
# Image data/without_signal/12784103_GMSK.png too small (4x1543), deleting.
# Error processing data/without_signal/12784103_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12979702_FM.png too small (1x1399), deleting.
# Error processing data/without_signal/12979702_FM.png: name 'input_path' is not defined
# Image data/without_signal/12781801_GMSK.png too small (4x1112), deleting.
# Error processing data/without_signal/12781801_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12979918_GMSK.png too small (38x1544), deleting.
# Error processing data/without_signal/12979918_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12773294_FM.png too small (3x1535), deleting.
# Error processing data/without_signal/12773294_FM.png: name 'input_path' is not defined
# Image data/without_signal/12944928_FM.png too small (3x1525), deleting.
# Error processing data/without_signal/12944928_FM.png: name 'input_path' is not defined
# Image data/without_signal/12838618_FM.png too small (3x1527), deleting.
# Error processing data/without_signal/12838618_FM.png: name 'input_path' is not defined
# Image data/without_signal/12775573_FM.png too small (1x1364), deleting.
# Error processing data/without_signal/12775573_FM.png: name 'input_path' is not defined
# Image data/without_signal/12839194_MSK AX.100 Mode 5.png too small (2x1525), deleting.
# Error processing data/without_signal/12839194_MSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12934306_FM.png too small (1x1526), deleting.
# Error processing data/without_signal/12934306_FM.png: name 'input_path' is not defined
# Image data/without_signal/12889857_GFSK.png too small (1x1538), deleting.
# Error processing data/without_signal/12889857_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12966439_BPSK.png too small (1x1506), deleting.
# Error processing data/without_signal/12966439_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12842609_BPSK.png too small (1x1523), deleting.
# Error processing data/without_signal/12842609_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12900308_GMSK.png too small (3x1543), deleting.
# Error processing data/without_signal/12900308_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12856786_FSK.png too small (3x1539), deleting.
# Error processing data/without_signal/12856786_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12951249_CW.png too small (2x1506), deleting.
# Error processing data/without_signal/12951249_CW.png: name 'input_path' is not defined
# Image data/without_signal/12846768_FM.png too small (1x1521), deleting.
# Error processing data/without_signal/12846768_FM.png: name 'input_path' is not defined
# Image data/without_signal/12884416_GMSK.png too small (3x1537), deleting.
# Error processing data/without_signal/12884416_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12995385_GMSK.png too small (7x1544), deleting.
# Error processing data/without_signal/12995385_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12909024_GMSK.png too small (2x1539), deleting.
# Error processing data/without_signal/12909024_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12760170_FM.png too small (2x1534), deleting.
# Error processing data/without_signal/12760170_FM.png: name 'input_path' is not defined
# Image data/without_signal/12796984_FSK.png too small (3x967), deleting.
# Error processing data/without_signal/12796984_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12801497_CW.png too small (1x1517), deleting.
# Error processing data/without_signal/12801497_CW.png: name 'input_path' is not defined
# Image data/without_signal/12792462_FM.png too small (4x1537), deleting.
# Error processing data/without_signal/12792462_FM.png: name 'input_path' is not defined
# Image data/without_signal/12765725_GMSK.png too small (1x1478), deleting.
# Error processing data/without_signal/12765725_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12807270_CW.png too small (1x1437), deleting.
# Error processing data/without_signal/12807270_CW.png: name 'input_path' is not defined
# Image data/without_signal/12976554_GMSK.png too small (3x66), deleting.
# Error processing data/without_signal/12976554_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12842801_GFSK.png too small (1x1520), deleting.
# Error processing data/without_signal/12842801_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12840338_FM.png too small (1x1430), deleting.
# Error processing data/without_signal/12840338_FM.png: name 'input_path' is not defined
# Image data/without_signal/12821290_GMSK.png too small (1x1460), deleting.
# Error processing data/without_signal/12821290_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12957431_GMSK.png too small (2x1533), deleting.
# Error processing data/without_signal/12957431_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12770291_FM.png too small (1x1329), deleting.
# Error processing data/without_signal/12770291_FM.png: name 'input_path' is not defined
# Image data/without_signal/12793876_SSTV.png too small (4x1531), deleting.
# Error processing data/without_signal/12793876_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12980030_FSK AX.100 Mode 5.png too small (2x1504), deleting.
# Error processing data/without_signal/12980030_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12835519_GFSK.png too small (1x1530), deleting.
# Error processing data/without_signal/12835519_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12988628_GFSK.png too small (1x1507), deleting.
# Error processing data/without_signal/12988628_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12981285_FSK AX.25 G3RUH.png too small (1x1388), deleting.
# Error processing data/without_signal/12981285_FSK AX.25 G3RUH.png: name 'input_path' is not defined
# Image data/without_signal/12815006_FM.png too small (1x1262), deleting.
# Error processing data/without_signal/12815006_FM.png: name 'input_path' is not defined
# Image data/without_signal/12821731_FSK.png too small (1x1228), deleting.
# Error processing data/without_signal/12821731_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12774339_LoRa.png too small (2x1523), deleting.
# Error processing data/without_signal/12774339_LoRa.png: name 'input_path' is not defined
# Image data/without_signal/12907810_SSTV.png too small (3x1529), deleting.
# Error processing data/without_signal/12907810_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12823241_BPSK.png too small (1x1517), deleting.
# Error processing data/without_signal/12823241_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12912346_GFSK.png too small (2x1505), deleting.
# Error processing data/without_signal/12912346_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12897758_FM.png too small (2x1525), deleting.
# Error processing data/without_signal/12897758_FM.png: name 'input_path' is not defined
# Image data/without_signal/12924378_FM.png too small (18x1543), deleting.
# Error processing data/without_signal/12924378_FM.png: name 'input_path' is not defined
# Image data/without_signal/12784160_FSK.png too small (1x1527), deleting.
# Error processing data/without_signal/12784160_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12791345_FM.png too small (1x1354), deleting.
# Error processing data/without_signal/12791345_FM.png: name 'input_path' is not defined
# Image data/without_signal/12901365_FM.png too small (1x1466), deleting.
# Error processing data/without_signal/12901365_FM.png: name 'input_path' is not defined
# Image data/without_signal/12991581_GFSK.png too small (17x1539), deleting.
# Error processing data/without_signal/12991581_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12794958_CW.png too small (3x1531), deleting.
# Error processing data/without_signal/12794958_CW.png: name 'input_path' is not defined
# Image data/without_signal/12959814_GMSK.png too small (8x1543), deleting.
# Error processing data/without_signal/12959814_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12765612_GMSK.png too small (1x1498), deleting.
# Error processing data/without_signal/12765612_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12898612_FM.png too small (19x1544), deleting.
# Error processing data/without_signal/12898612_FM.png: name 'input_path' is not defined
# Image data/without_signal/12927552_LoRa.png too small (2x1537), deleting.
# Error processing data/without_signal/12927552_LoRa.png: name 'input_path' is not defined
# Image data/without_signal/12945331_FSK AX.100 Mode 5.png too small (1x1258), deleting.
# Error processing data/without_signal/12945331_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12989862_FM.png too small (9x1536), deleting.
# Error processing data/without_signal/12989862_FM.png: name 'input_path' is not defined
# Image data/without_signal/13004280_GMSK.png too small (1x1526), deleting.
# Error processing data/without_signal/13004280_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12784157_GMSK.png too small (8x1544), deleting.
# Error processing data/without_signal/12784157_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12993347_CW.png too small (2x1476), deleting.
# Error processing data/without_signal/12993347_CW.png: name 'input_path' is not defined
# Image data/without_signal/13030515_FSK AX.100 Mode 5.png too small (4x1541), deleting.
# Error processing data/without_signal/13030515_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12802597_GFSK.png too small (3x1451), deleting.
# Error processing data/without_signal/12802597_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12839008_AFSK.png too small (25x1542), deleting.
# Error processing data/without_signal/12839008_AFSK.png: name 'input_path' is not defined
# Image data/without_signal/12792698_CW.png too small (1x1527), deleting.
# Error processing data/without_signal/12792698_CW.png: name 'input_path' is not defined
# Image data/without_signal/12764846_FM.png too small (2x1527), deleting.
# Error processing data/without_signal/12764846_FM.png: name 'input_path' is not defined
# Image data/without_signal/12982112_FM.png too small (1x1504), deleting.
# Error processing data/without_signal/12982112_FM.png: name 'input_path' is not defined
# Image data/without_signal/12862316_GFSK.png too small (52x1544), deleting.
# Error processing data/without_signal/12862316_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12809593_GFSK.png too small (1x1522), deleting.
# Error processing data/without_signal/12809593_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12904174_BPSK.png too small (1x1174), deleting.
# Error processing data/without_signal/12904174_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12813789_BPSK.png too small (1x1495), deleting.
# Error processing data/without_signal/12813789_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12833954_FM.png too small (1x1533), deleting.
# Error processing data/without_signal/12833954_FM.png: name 'input_path' is not defined
# Image data/without_signal/12813124_GMSK.png too small (216x1087), deleting.
# Error processing data/without_signal/12813124_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12961989_GMSK.png too small (3x1522), deleting.
# Error processing data/without_signal/12961989_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12795981_AFSK TUBiX10.png too small (1x1435), deleting.
# Error processing data/without_signal/12795981_AFSK TUBiX10.png: name 'input_path' is not defined
# Image data/without_signal/12940264_FSK.png too small (3x1168), deleting.
# Error processing data/without_signal/12940264_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12859123_CW.png too small (9x1429), deleting.
# Error processing data/without_signal/12859123_CW.png: name 'input_path' is not defined
# Image data/without_signal/12869412_MSK.png too small (2x1481), deleting.
# Error processing data/without_signal/12869412_MSK.png: name 'input_path' is not defined
# Image data/without_signal/12820018_FM.png too small (1x1474), deleting.
# Error processing data/without_signal/12820018_FM.png: name 'input_path' is not defined
# Image data/without_signal/13006503_DUV.png too small (598x254), deleting.
# Error processing data/without_signal/13006503_DUV.png: name 'input_path' is not defined
# Image data/without_signal/12951081_AFSK TUBiX10.png too small (1x1492), deleting.
# Error processing data/without_signal/12951081_AFSK TUBiX10.png: name 'input_path' is not defined
# Image data/without_signal/12773292_GMSK.png too small (2x1534), deleting.
# Error processing data/without_signal/12773292_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12900716_GMSK.png too small (4x1541), deleting.
# Error processing data/without_signal/12900716_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12798481_FSK.png too small (6x1544), deleting.
# Error processing data/without_signal/12798481_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12782206_GMSK USP.png too small (1x64), deleting.
# Error processing data/without_signal/12782206_GMSK USP.png: name 'input_path' is not defined
# Image data/without_signal/12909171_FM.png too small (1x1505), deleting.
# Error processing data/without_signal/12909171_FM.png: name 'input_path' is not defined
# Image data/without_signal/12774332_LoRa.png too small (1x1372), deleting.
# Error processing data/without_signal/12774332_LoRa.png: name 'input_path' is not defined
# Image data/without_signal/12780597_FSK AX.25 G3RUH.png too small (1x1440), deleting.
# Error processing data/without_signal/12780597_FSK AX.25 G3RUH.png: name 'input_path' is not defined
# Image data/without_signal/12834244_MSK AX.100 Mode 5.png too small (29x1544), deleting.
# Error processing data/without_signal/12834244_MSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12920754_FSK.png too small (4x1003), deleting.
# Error processing data/without_signal/12920754_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12866096_FSK.png too small (1x1373), deleting.
# Error processing data/without_signal/12866096_FSK.png: name 'input_path' is not defined
# Image data/without_signal/13015166_SSTV.png too small (6x1525), deleting.
# Error processing data/without_signal/13015166_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12869390_BPSK.png too small (3x1505), deleting.
# Error processing data/without_signal/12869390_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12889240_BPSK.png too small (23x3), deleting.
# Error processing data/without_signal/12889240_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/13015939_SSTV.png too small (6x1531), deleting.
# Error processing data/without_signal/13015939_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12795464_LRPT.png too small (1x1510), deleting.
# Error processing data/without_signal/12795464_LRPT.png: name 'input_path' is not defined
# Image data/without_signal/12832810_SSTV.png too small (3x1535), deleting.
# Error processing data/without_signal/12832810_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12869248_LRPT.png too small (13x1453), deleting.
# Error processing data/without_signal/12869248_LRPT.png: name 'input_path' is not defined
# Image data/without_signal/12812184_SSTV.png too small (8x1533), deleting.
# Error processing data/without_signal/12812184_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12784384_DUV.png too small (2x1494), deleting.
# Error processing data/without_signal/12784384_DUV.png: name 'input_path' is not defined
# Image data/without_signal/12804377_SSTV.png too small (6x1345), deleting.
# Error processing data/without_signal/12804377_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12865829_FM.png too small (1x1356), deleting.
# Error processing data/without_signal/12865829_FM.png: name 'input_path' is not defined
# Image data/without_signal/12800000_DUV.png too small (5x1351), deleting.
# Error processing data/without_signal/12800000_DUV.png: name 'input_path' is not defined
# Image data/without_signal/12989299_GFSK.png too small (2x1502), deleting.
# Error processing data/without_signal/12989299_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12816279_FSK.png too small (1x1104), deleting.
# Error processing data/without_signal/12816279_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12977707_FM.png too small (2x1501), deleting.
# Error processing data/without_signal/12977707_FM.png: name 'input_path' is not defined
# Image data/without_signal/12982527_SSTV.png too small (1x1525), deleting.
# Error processing data/without_signal/12982527_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12760718_FSK.png too small (1x1332), deleting.
# Error processing data/without_signal/12760718_FSK.png: name 'input_path' is not defined
# Image data/without_signal/13001392_CW.png too small (16x1484), deleting.
# Error processing data/without_signal/13001392_CW.png: name 'input_path' is not defined
# Image data/without_signal/12809030_FSK AX.100 Mode 5.png too small (1x1517), deleting.
# Error processing data/without_signal/12809030_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/13020545_GFSK.png too small (1x1483), deleting.
# Error processing data/without_signal/13020545_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12833991_FM.png too small (187x1537), deleting.
# Error processing data/without_signal/12833991_FM.png: name 'input_path' is not defined
# Image data/without_signal/12805760_BPSK.png too small (1x1514), deleting.
# Error processing data/without_signal/12805760_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12956598_FM.png too small (1x1423), deleting.
# Error processing data/without_signal/12956598_FM.png: name 'input_path' is not defined
# Image data/without_signal/12773291_FSK.png too small (3x1536), deleting.
# Error processing data/without_signal/12773291_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12834100_MSK AX.100 Mode 5.png too small (3x1534), deleting.
# Error processing data/without_signal/12834100_MSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12979683_BPSK.png too small (1x1378), deleting.
# Error processing data/without_signal/12979683_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12801692_BPSK.png too small (1x1434), deleting.
# Error processing data/without_signal/12801692_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12779816_CW.png too small (1x1513), deleting.
# Error processing data/without_signal/12779816_CW.png: name 'input_path' is not defined
# Image data/without_signal/12820645_FSK AX.100 Mode 5.png too small (1x1477), deleting.
# Error processing data/without_signal/12820645_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12819464_FM.png too small (3x1503), deleting.
# Error processing data/without_signal/12819464_FM.png: name 'input_path' is not defined
# Image data/without_signal/12785716_BPSK.png too small (2x1530), deleting.
# Error processing data/without_signal/12785716_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12826585_GMSK.png too small (1x1535), deleting.
# Error processing data/without_signal/12826585_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12813241_GMSK.png too small (21x1468), deleting.
# Error processing data/without_signal/12813241_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12799724_FM.png too small (13x1532), deleting.
# Error processing data/without_signal/12799724_FM.png: name 'input_path' is not defined
# Image data/without_signal/12760553_FM.png too small (617x1475), deleting.
# Error processing data/without_signal/12760553_FM.png: name 'input_path' is not defined
# Image data/without_signal/12995550_GMSK.png too small (5x80), deleting.
# Error processing data/without_signal/12995550_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12789703_FM.png too small (1x1521), deleting.
# Error processing data/without_signal/12789703_FM.png: name 'input_path' is not defined
# Image data/without_signal/12886596_GFSK.png too small (1x1462), deleting.
# Error processing data/without_signal/12886596_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12812185_BPSK.png too small (2x1455), deleting.
# Error processing data/without_signal/12812185_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12913089_FM.png too small (4x1443), deleting.
# Error processing data/without_signal/12913089_FM.png: name 'input_path' is not defined
# Image data/without_signal/12944465_FM.png too small (30x1544), deleting.
# Error processing data/without_signal/12944465_FM.png: name 'input_path' is not defined
# Image data/without_signal/12971276_AFSK TUBiX10.png too small (2x1498), deleting.
# Error processing data/without_signal/12971276_AFSK TUBiX10.png: name 'input_path' is not defined
# Image data/without_signal/12857105_SSTV.png too small (9x1507), deleting.
# Error processing data/without_signal/12857105_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12814389_AFSK TUBiX10.png too small (1x1533), deleting.
# Error processing data/without_signal/12814389_AFSK TUBiX10.png: name 'input_path' is not defined
# Image data/without_signal/12998998_SSTV.png too small (6x1531), deleting.
# Error processing data/without_signal/12998998_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12826285_FM.png too small (10x1534), deleting.
# Error processing data/without_signal/12826285_FM.png: name 'input_path' is not defined
# Image data/without_signal/12772824_FM.png too small (3x1468), deleting.
# Error processing data/without_signal/12772824_FM.png: name 'input_path' is not defined
# Image data/without_signal/12965838_GMSK.png too small (1x1419), deleting.
# Error processing data/without_signal/12965838_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12820184_FM.png too small (2x1449), deleting.
# Error processing data/without_signal/12820184_FM.png: name 'input_path' is not defined
# Image data/without_signal/13009908_FSK AX.100 Mode 5.png too small (1x1274), deleting.
# Error processing data/without_signal/13009908_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12995411_GMSK.png too small (174x1537), deleting.
# Error processing data/without_signal/12995411_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12775170_CW.png too small (1x1478), deleting.
# Error processing data/without_signal/12775170_CW.png: name 'input_path' is not defined
# Image data/without_signal/12882445_GMSK.png too small (214x1144), deleting.
# Error processing data/without_signal/12882445_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12903684_CW.png too small (1x1222), deleting.
# Error processing data/without_signal/12903684_CW.png: name 'input_path' is not defined
# Image data/without_signal/12829614_GMSK.png too small (392x1537), deleting.
# Error processing data/without_signal/12829614_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12796166_FM.png too small (1x1512), deleting.
# Error processing data/without_signal/12796166_FM.png: name 'input_path' is not defined
# Image data/without_signal/12798885_CW.png too small (1x1535), deleting.
# Error processing data/without_signal/12798885_CW.png: name 'input_path' is not defined
# Image data/without_signal/12843231_GFSK.png too small (1x1471), deleting.
# Error processing data/without_signal/12843231_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12758750_FM.png too small (2x1509), deleting.
# Error processing data/without_signal/12758750_FM.png: name 'input_path' is not defined
# Image data/without_signal/13006284_GMSK.png too small (4x1540), deleting.
# Error processing data/without_signal/13006284_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12807274_LRPT.png too small (1x1535), deleting.
# Error processing data/without_signal/12807274_LRPT.png: name 'input_path' is not defined
# Image data/without_signal/12832266_CW.png too small (1x1332), deleting.
# Error processing data/without_signal/12832266_CW.png: name 'input_path' is not defined
# Image data/without_signal/12766571_FM.png too small (1x1467), deleting.
# Error processing data/without_signal/12766571_FM.png: name 'input_path' is not defined
# Image data/without_signal/12823662_FM.png too small (1x1515), deleting.
# Error processing data/without_signal/12823662_FM.png: name 'input_path' is not defined
# Image data/without_signal/12802384_FSK.png too small (8x1544), deleting.
# Error processing data/without_signal/12802384_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12770976_BPSK.png too small (2x1528), deleting.
# Error processing data/without_signal/12770976_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12999307_GMSK.png too small (1x1436), deleting.
# Error processing data/without_signal/12999307_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12986616_GMSK.png too small (1x1529), deleting.
# Error processing data/without_signal/12986616_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12792937_GMSK.png too small (1x1498), deleting.
# Error processing data/without_signal/12792937_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/13004812_GMSK.png too small (14x1544), deleting.
# Error processing data/without_signal/13004812_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12793593_AFSK TUBiX10.png too small (1x1523), deleting.
# Error processing data/without_signal/12793593_AFSK TUBiX10.png: name 'input_path' is not defined
# Image data/without_signal/13008874_CW.png too small (2x1514), deleting.
# Error processing data/without_signal/13008874_CW.png: name 'input_path' is not defined
# Image data/without_signal/12809603_FM.png too small (1x1452), deleting.
# Error processing data/without_signal/12809603_FM.png: name 'input_path' is not defined
# Image data/without_signal/12920883_FSK.png too small (5x1430), deleting.
# Error processing data/without_signal/12920883_FSK.png: name 'input_path' is not defined
# Image data/without_signal/13012204_MSK AX.100 Mode 5.png too small (1x1303), deleting.
# Error processing data/without_signal/13012204_MSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12857246_FM.png too small (3x1403), deleting.
# Error processing data/without_signal/12857246_FM.png: name 'input_path' is not defined
# Image data/without_signal/12860412_GFSK.png too small (2x1490), deleting.
# Error processing data/without_signal/12860412_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12766572_FSK.png too small (3x1510), deleting.
# Error processing data/without_signal/12766572_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12865981_CW.png too small (2x1526), deleting.
# Error processing data/without_signal/12865981_CW.png: name 'input_path' is not defined
# Image data/without_signal/12896208_BPSK.png too small (1x1440), deleting.
# Error processing data/without_signal/12896208_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12848632_GMSK.png too small (2x1484), deleting.
# Error processing data/without_signal/12848632_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12816841_FM.png too small (5x1507), deleting.
# Error processing data/without_signal/12816841_FM.png: name 'input_path' is not defined
# ...
# Error processing data/without_signal/13020901_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12797335_FM.png too small (3x1420), deleting.
# Error processing data/without_signal/12797335_FM.png: name 'input_path' is not defined
# Image data/without_signal/12897544_QPSK.png too small (2x1524), deleting.
# Error processing data/without_signal/12897544_QPSK.png: name 'input_path' is not defined
# Image data/without_signal/12834008_MSK AX.100 Mode 5.png too small (1x632), deleting.
# Error processing data/without_signal/12834008_MSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12921422_GMSK.png too small (1x630), deleting.
# Error processing data/without_signal/12921422_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12988398_FM.png too small (2x1504), deleting.
# Error processing data/without_signal/12988398_FM.png: name 'input_path' is not defined
# Image data/without_signal/12772279_LRPT.png too small (1x1531), deleting.
# Error processing data/without_signal/12772279_LRPT.png: name 'input_path' is not defined
# Image data/without_signal/12913511_BPSK.png too small (1x1512), deleting.
# Error processing data/without_signal/12913511_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12997602_FSK AX.100 Mode 5.png too small (1x1264), deleting.
# Error processing data/without_signal/12997602_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12769774_FM.png too small (1x1489), deleting.
# Error processing data/without_signal/12769774_FM.png: name 'input_path' is not defined
# Image data/without_signal/13019958_FSK.png too small (1x1499), deleting.
# Error processing data/without_signal/13019958_FSK.png: name 'input_path' is not defined
# Image data/without_signal/13043338_GFSK.png too small (2x1506), deleting.
# Error processing data/without_signal/13043338_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12919892_BPSK.png too small (1x1465), deleting.
# Error processing data/without_signal/12919892_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12839013_CW.png too small (8x1544), deleting.
# Error processing data/without_signal/12839013_CW.png: name 'input_path' is not defined
# Image data/without_signal/12915519_GMSK.png too small (3x1410), deleting.
# Error processing data/without_signal/12915519_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12781615_BPSK.png too small (1x1512), deleting.
# Error processing data/without_signal/12781615_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12858933_FM.png too small (1x1481), deleting.
# Error processing data/without_signal/12858933_FM.png: name 'input_path' is not defined
# Image data/without_signal/12816541_BPSK.png too small (1x1543), deleting.
# Error processing data/without_signal/12816541_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12843582_FM.png too small (4x1295), deleting.
# Error processing data/without_signal/12843582_FM.png: name 'input_path' is not defined
# Image data/without_signal/13013690_FM.png too small (2x1497), deleting.
# Error processing data/without_signal/13013690_FM.png: name 'input_path' is not defined
# Image data/without_signal/12980601_GFSK.png too small (1x1414), deleting.
# Error processing data/without_signal/12980601_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12807813_GMSK.png too small (2x1544), deleting.
# Error processing data/without_signal/12807813_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12847087_GFSK.png too small (37x1537), deleting.
# Error processing data/without_signal/12847087_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12766258_BPSK.png too small (1x1535), deleting.
# Error processing data/without_signal/12766258_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12971040_BPSK.png too small (2x1534), deleting.
# Error processing data/without_signal/12971040_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12898432_CW.png too small (3x1468), deleting.
# Error processing data/without_signal/12898432_CW.png: name 'input_path' is not defined
# Image data/without_signal/12822626_FM.png too small (2x1511), deleting.
# Error processing data/without_signal/12822626_FM.png: name 'input_path' is not defined
# Image data/without_signal/12853671_FM.png too small (2x1536), deleting.
# Error processing data/without_signal/12853671_FM.png: name 'input_path' is not defined
# Image data/without_signal/12776031_CW.png too small (4x1493), deleting.
# Error processing data/without_signal/12776031_CW.png: name 'input_path' is not defined
# Image data/without_signal/13001220_LRPT.png too small (2x1524), deleting.
# Error processing data/without_signal/13001220_LRPT.png: name 'input_path' is not defined
# Image data/without_signal/12823679_FSK AX.25 G3RUH.png too small (8x1544), deleting.
# Error processing data/without_signal/12823679_FSK AX.25 G3RUH.png: name 'input_path' is not defined
# Image data/without_signal/12969599_BPSK.png too small (2x1522), deleting.
# Error processing data/without_signal/12969599_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12777272_FSK AX.100 Mode 5.png too small (4x1466), deleting.
# Error processing data/without_signal/12777272_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12818424_FSK AX.100 Mode 5.png too small (242x1537), deleting.
# Error processing data/without_signal/12818424_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12902057_GFSK.png too small (20x1544), deleting.
# Error processing data/without_signal/12902057_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12882426_GMSK.png too small (190x245), deleting.
# Error processing data/without_signal/12882426_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12895418_BPSK.png too small (2x1476), deleting.
# Error processing data/without_signal/12895418_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12790347_FSK.png too small (1x788), deleting.
# Error processing data/without_signal/12790347_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12858842_FM.png too small (2x1497), deleting.
# Error processing data/without_signal/12858842_FM.png: name 'input_path' is not defined
# Image data/without_signal/12772672_USB.png too small (1x1405), deleting.
# Error processing data/without_signal/12772672_USB.png: name 'input_path' is not defined
# Image data/without_signal/12843446_LRPT.png too small (1x1533), deleting.
# Error processing data/without_signal/12843446_LRPT.png: name 'input_path' is not defined
# Image data/without_signal/12979532_CW.png too small (2x1533), deleting.
# Error processing data/without_signal/12979532_CW.png: name 'input_path' is not defined
# Image data/without_signal/13017321_GMSK.png too small (5x1543), deleting.
# Error processing data/without_signal/13017321_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12944164_BPSK.png too small (1x1450), deleting.
# Error processing data/without_signal/12944164_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12946067_GMSK.png too small (236x1537), deleting.
# Error processing data/without_signal/12946067_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12865971_SSTV.png too small (2x1536), deleting.
# Error processing data/without_signal/12865971_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12884259_LoRa.png too small (5x1535), deleting.
# Error processing data/without_signal/12884259_LoRa.png: name 'input_path' is not defined
# Image data/without_signal/12867189_GMSK.png too small (1x1495), deleting.
# Error processing data/without_signal/12867189_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12828485_AFSK.png too small (1x1459), deleting.
# Error processing data/without_signal/12828485_AFSK.png: name 'input_path' is not defined
# Image data/without_signal/12766145_FM.png too small (2x1502), deleting.
# Error processing data/without_signal/12766145_FM.png: name 'input_path' is not defined
# Image data/without_signal/12844846_GFSK.png too small (17x1348), deleting.
# Error processing data/without_signal/12844846_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12840022_SSTV.png too small (4x1534), deleting.
# Error processing data/without_signal/12840022_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12801087_GMSK.png too small (1x1457), deleting.
# Error processing data/without_signal/12801087_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12834207_MSK AX.100 Mode 5.png too small (12x1544), deleting.
# Error processing data/without_signal/12834207_MSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12834743_GMSK.png too small (43x726), deleting.
# Error processing data/without_signal/12834743_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12880357_SSTV.png too small (20x1420), deleting.
# Error processing data/without_signal/12880357_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12945022_GMSK.png too small (4x1480), deleting.
# Error processing data/without_signal/12945022_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12911816_FM.png too small (1x1534), deleting.
# Error processing data/without_signal/12911816_FM.png: name 'input_path' is not defined
# Image data/without_signal/12914573_GFSK.png too small (6x1538), deleting.
# Error processing data/without_signal/12914573_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12824503_FM.png too small (1x1433), deleting.
# Error processing data/without_signal/12824503_FM.png: name 'input_path' is not defined
# Image data/without_signal/12971330_FSK.png too small (1x1486), deleting.
# Error processing data/without_signal/12971330_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12919559_FSK AX.25 G3RUH.png too small (1x1529), deleting.
# Error processing data/without_signal/12919559_FSK AX.25 G3RUH.png: name 'input_path' is not defined
# Image data/without_signal/12945711_GMSK.png too small (3x1530), deleting.
# Error processing data/without_signal/12945711_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12847477_GFSK.png too small (2x1534), deleting.
# Error processing data/without_signal/12847477_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12926155_FSK AX.100 Mode 5.png too small (1x1382), deleting.
# Error processing data/without_signal/12926155_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12910354_LoRa.png too small (19x1544), deleting.
# Error processing data/without_signal/12910354_LoRa.png: name 'input_path' is not defined
# Image data/without_signal/12788478_SSTV.png too small (1x1533), deleting.
# Error processing data/without_signal/12788478_SSTV.png: name 'input_path' is not defined
# Image data/without_signal/12998018_FM.png too small (1x1505), deleting.
# Error processing data/without_signal/12998018_FM.png: name 'input_path' is not defined
# Image data/without_signal/12933363_GMSK.png too small (1x1517), deleting.
# Error processing data/without_signal/12933363_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12809664_FSK.png too small (1x1398), deleting.
# Error processing data/without_signal/12809664_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12993828_GMSK.png too small (2x1521), deleting.
# Error processing data/without_signal/12993828_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12960759_BPSK.png too small (1x1513), deleting.
# Error processing data/without_signal/12960759_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12813762_FM.png too small (617x1020), deleting.
# Error processing data/without_signal/12813762_FM.png: name 'input_path' is not defined
# Image data/without_signal/13007418_LoRa.png too small (2x1521), deleting.
# Error processing data/without_signal/13007418_LoRa.png: name 'input_path' is not defined
# Image data/without_signal/12773316_GMSK.png too small (9x1537), deleting.
# Error processing data/without_signal/12773316_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12848682_BPSK.png too small (2x1510), deleting.
# Error processing data/without_signal/12848682_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12833709_FSK AX.100 Mode 5.png too small (6x1544), deleting.
# Error processing data/without_signal/12833709_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12773288_BPSK.png too small (1x1534), deleting.
# Error processing data/without_signal/12773288_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12793428_CW.png too small (3x1495), deleting.
# Error processing data/without_signal/12793428_CW.png: name 'input_path' is not defined
# Image data/without_signal/12970103_BPSK.png too small (3x1520), deleting.
# Error processing data/without_signal/12970103_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12806078_FSK AX.100 Mode 5.png too small (4x1510), deleting.
# Error processing data/without_signal/12806078_FSK AX.100 Mode 5.png: name 'input_path' is not defined
# Image data/without_signal/12963132_CW.png too small (32x1489), deleting.
# Error processing data/without_signal/12963132_CW.png: name 'input_path' is not defined
# Image data/without_signal/12927497_GFSK.png too small (20x1537), deleting.
# Error processing data/without_signal/12927497_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12777144_GFSK.png too small (2x1521), deleting.
# Error processing data/without_signal/12777144_GFSK.png: name 'input_path' is not defined
# Image data/without_signal/12921807_CW.png too small (7x980), deleting.
# Error processing data/without_signal/12921807_CW.png: name 'input_path' is not defined
# Image data/without_signal/12865534_GMSK.png too small (2x1529), deleting.
# Error processing data/without_signal/12865534_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12934838_BPSK.png too small (1x1518), deleting.
# Error processing data/without_signal/12934838_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12797826_FSK.png too small (2x1535), deleting.
# Error processing data/without_signal/12797826_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12778599_FSK.png too small (3x1537), deleting.
# Error processing data/without_signal/12778599_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12848683_FM.png too small (2x1531), deleting.
# Error processing data/without_signal/12848683_FM.png: name 'input_path' is not defined
# Image data/without_signal/12785513_CW.png too small (4x1387), deleting.
# Error processing data/without_signal/12785513_CW.png: name 'input_path' is not defined
# Image data/without_signal/12885248_BPSK.png too small (2x1522), deleting.
# Error processing data/without_signal/12885248_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12802892_BPSK.png too small (5x1502), deleting.
# Error processing data/without_signal/12802892_BPSK.png: name 'input_path' is not defined
# Image data/without_signal/12922172_CW.png too small (1x1465), deleting.
# Error processing data/without_signal/12922172_CW.png: name 'input_path' is not defined
# Image data/without_signal/12935599_GMSK.png too small (63x1544), deleting.
# Error processing data/without_signal/12935599_GMSK.png: name 'input_path' is not defined
# Image data/without_signal/12856800_FSK.png too small (4x1544), deleting.
# Error processing data/without_signal/12856800_FSK.png: name 'input_path' is not defined
# Image data/without_signal/12962849_FSK.png too small (1x1481), deleting.
# Error processing data/without_signal/12962849_FSK.png: name 'input_path' is not defined
# Finished processing without-signal images.

# %%
def final_dimension_cleanup():
    datadir_with = 'data/with_signal'
    datadir_without = 'data/without_signal'

    for filepath in glob.glob(os.path.join(datadir_with, '*.png')):
        img = cv2.imread(filepath)
        if img is None:
            continue
        h, w = img.shape[:2]
        if h != 750 and w != 200:
            print(f"Deleting unusually small image: {filepath} with size {w}x{h}")
            os.remove(filepath)

    print("Cleaned up with-signal images.")

    for filepath in glob.glob(os.path.join(datadir_without, '*.png')):
        img = cv2.imread(filepath)
        if img is None:
            continue
        h, w = img.shape[:2]
        if h != 750 and w != 200:
            print(f"Deleting unusually small image: {filepath} with size {w}x{h}")
            os.remove(filepath)
    print("Cleaned up without-signal images.")

# %%
if True: final_dimension_cleanup()
# Out:
# Cleaned up with-signal images.
# Deleting unusually small image: data/without_signal/12833378_FSK AX.100 Mode 5.png with size 2x1543
# Deleting unusually small image: data/without_signal/12789005_FM.png with size 1x1405
# Deleting unusually small image: data/without_signal/12802333_BPSK.png with size 4x1398
# Deleting unusually small image: data/without_signal/12845138_FSK AX.100 Mode 5.png with size 4x843
# Deleting unusually small image: data/without_signal/12775189_SSTV.png with size 4x1511
# Deleting unusually small image: data/without_signal/12860964_BPSK.png with size 1x138
# Deleting unusually small image: data/without_signal/12898200_BPSK.png with size 1x1467
# Deleting unusually small image: data/without_signal/12980085_BPSK.png with size 4x1512
# Deleting unusually small image: data/without_signal/13011850_FM.png with size 2x1515
# Deleting unusually small image: data/without_signal/12834085_MSK AX.100 Mode 5.png with size 1x1530
# Deleting unusually small image: data/without_signal/13012875_CW.png with size 1x1397
# Deleting unusually small image: data/without_signal/12933719_FM.png with size 2x1462
# Deleting unusually small image: data/without_signal/13009222_USB.png with size 9x1504
# Deleting unusually small image: data/without_signal/12802316_GFSK.png with size 8x1534
# Deleting unusually small image: data/without_signal/12908376_FM.png with size 3x1515
# Deleting unusually small image: data/without_signal/12998731_CW.png with size 2x1526
# Deleting unusually small image: data/without_signal/12962414_CW.png with size 1x1394
# Deleting unusually small image: data/without_signal/13009809_CW.png with size 2x1534
# Deleting unusually small image: data/without_signal/12834910_GMSK.png with size 1x1497
# Deleting unusually small image: data/without_signal/12818648_MSK AX.100 Mode 5.png with size 1x1537
# Deleting unusually small image: data/without_signal/12777876_LRPT.png with size 3x1505
# Deleting unusually small image: data/without_signal/12948968_GMSK.png with size 14x1543
# Deleting unusually small image: data/without_signal/12944689_FSK.png with size 2x1411
# Deleting unusually small image: data/without_signal/12907936_FSK AX.100 Mode 5.png with size 1x1508
# Deleting unusually small image: data/without_signal/12983235_FSK.png with size 2x1431
# Deleting unusually small image: data/without_signal/12829637_GMSK.png with size 346x1537
# Deleting unusually small image: data/without_signal/12832827_CW.png with size 2x1491
# Deleting unusually small image: data/without_signal/12805007_AFSK.png with size 4x1396
# Deleting unusually small image: data/without_signal/13014369_AFSK.png with size 26x1398
# Deleting unusually small image: data/without_signal/12944228_FM.png with size 1x1448
# Deleting unusually small image: data/without_signal/12913199_FM.png with size 2x1536
# Deleting unusually small image: data/without_signal/12843436_GMSK.png with size 1x1513
# Deleting unusually small image: data/without_signal/12944473_FSK.png with size 1x1443
# Deleting unusually small image: data/without_signal/12973226_FSK.png with size 2x1530
# Deleting unusually small image: data/without_signal/12858047_GMSK.png with size 1x6
# Deleting unusually small image: data/without_signal/12856665_GMSK.png with size 2x1444
# Deleting unusually small image: data/without_signal/12759055_BPSK.png with size 1x1500
# Deleting unusually small image: data/without_signal/12875592_CW.png with size 5x1417
# Deleting unusually small image: data/without_signal/12930038_CW.png with size 1x1489
# Deleting unusually small image: data/without_signal/12831478_DUV.png with size 2x1529
# Deleting unusually small image: data/without_signal/12838889_CW.png with size 4x970
# Deleting unusually small image: data/without_signal/12809476_GMSK.png with size 15x1544
# Deleting unusually small image: data/without_signal/13015411_SSTV.png with size 1x1537
# Deleting unusually small image: data/without_signal/12881299_FM.png with size 1x1514
# Deleting unusually small image: data/without_signal/12970918_GMSK.png with size 2x1526
# Deleting unusually small image: data/without_signal/12762535_BPSK.png with size 2x1537
# Deleting unusually small image: data/without_signal/12809537_GMSK.png with size 26x1543
# Deleting unusually small image: data/without_signal/12774308_BPSK.png with size 1x1278
# Deleting unusually small image: data/without_signal/12863088_GFSK.png with size 154x1537
# Deleting unusually small image: data/without_signal/12819730_GMSK.png with size 11x1542
# Deleting unusually small image: data/without_signal/12759178_GFSK.png with size 1x1520
# Deleting unusually small image: data/without_signal/12934490_FM.png with size 2x1544
# Deleting unusually small image: data/without_signal/12824711_SSTV.png with size 5x1531
# Deleting unusually small image: data/without_signal/12848817_FM.png with size 1x1534
# Deleting unusually small image: data/without_signal/12895673_DUV.png with size 1x1519
# Deleting unusually small image: data/without_signal/12867687_FM.png with size 2x1509
# Deleting unusually small image: data/without_signal/12823818_BPSK.png with size 1x1479
# Deleting unusually small image: data/without_signal/12969343_MSK AX.100 Mode 5.png with size 3x1513
# Deleting unusually small image: data/without_signal/12926271_CW.png with size 1x1497
# Deleting unusually small image: data/without_signal/12778582_FSK AX.100 Mode 5.png with size 4x1533
# Deleting unusually small image: data/without_signal/12898359_DUV.png with size 2x1505
# Deleting unusually small image: data/without_signal/12899001_FSK.png with size 1x1221
# Deleting unusually small image: data/without_signal/12877186_CW.png with size 1x1367
# Deleting unusually small image: data/without_signal/12939464_BPSK.png with size 5x1528
# Deleting unusually small image: data/without_signal/12827415_FM.png with size 1x1506
# Deleting unusually small image: data/without_signal/12943707_FSK.png with size 1x1424
# Deleting unusually small image: data/without_signal/12843271_FSK.png with size 12x1352
# Deleting unusually small image: data/without_signal/12850694_FM.png with size 1x1506
# Deleting unusually small image: data/without_signal/12826513_FM.png with size 4x18
# Deleting unusually small image: data/without_signal/12781570_CW.png with size 4x1533
# Deleting unusually small image: data/without_signal/12990513_CW.png with size 1x1507
# Deleting unusually small image: data/without_signal/12971646_CW.png with size 1x1495
# Deleting unusually small image: data/without_signal/12996143_CW.png with size 5x1536
# Deleting unusually small image: data/without_signal/13010860_FM.png with size 1x1509
# Deleting unusually small image: data/without_signal/12944127_FM.png with size 1x1489
# Deleting unusually small image: data/without_signal/12775438_FM.png with size 1x1452
# Deleting unusually small image: data/without_signal/12845717_MSK AX.100 Mode 5.png with size 6x1544
# Deleting unusually small image: data/without_signal/12921152_FSK.png with size 1x974
# Deleting unusually small image: data/without_signal/12796720_GMSK.png with size 12x1528
# Deleting unusually small image: data/without_signal/13013733_CW.png with size 3x1495
# Deleting unusually small image: data/without_signal/12768024_BPSK.png with size 5x1532
# Deleting unusually small image: data/without_signal/12872740_GFSK.png with size 153x1537
# Deleting unusually small image: data/without_signal/12870087_GMSK.png with size 1x1295
# Deleting unusually small image: data/without_signal/12862632_SSTV.png with size 513x358
# Deleting unusually small image: data/without_signal/12779534_LoRa.png with size 2x1499
# Deleting unusually small image: data/without_signal/12901532_GFSK.png with size 1x2
# Deleting unusually small image: data/without_signal/12837740_FM.png with size 1x1425
# Deleting unusually small image: data/without_signal/12992076_FSK.png with size 8x1432
# Deleting unusually small image: data/without_signal/12950676_FM.png with size 1x1510
# Deleting unusually small image: data/without_signal/12823499_FSK AX.100 Mode 5.png with size 1x1449
# Deleting unusually small image: data/without_signal/12785234_FSK AX.100 Mode 5.png with size 2x1510
# Deleting unusually small image: data/without_signal/12892103_MSK AX.100 Mode 5.png with size 6x62
# Deleting unusually small image: data/without_signal/12920365_USB.png with size 1x1296
# Deleting unusually small image: data/without_signal/12845431_FSK AX.100 Mode 5.png with size 6x1543
# Deleting unusually small image: data/without_signal/12824534_BPSK.png with size 1x1472
# Deleting unusually small image: data/without_signal/12954365_GMSK.png with size 1x1352
# Deleting unusually small image: data/without_signal/12834736_GMSK.png with size 1x1543
# Deleting unusually small image: data/without_signal/12865833_BPSK.png with size 1x1519
# Deleting unusually small image: data/without_signal/12921893_GMSK.png with size 1x1463
# Deleting unusually small image: data/without_signal/13014906_CW.png with size 1x1521
# Deleting unusually small image: data/without_signal/12849508_BPSK.png with size 43x910
# Deleting unusually small image: data/without_signal/12915880_CW.png with size 1x1465
# Deleting unusually small image: data/without_signal/12833948_FM.png with size 18x1543
# Deleting unusually small image: data/without_signal/12974044_GFSK.png with size 1x1286
# Deleting unusually small image: data/without_signal/12768032_FSK AX.100 Mode 5.png with size 1x1530
# Deleting unusually small image: data/without_signal/12945668_FSK AX.25 G3RUH.png with size 469x186
# Deleting unusually small image: data/without_signal/12944752_FM.png with size 7x1384
# Deleting unusually small image: data/without_signal/12780169_FM.png with size 2x1535
# Deleting unusually small image: data/without_signal/12962994_GMSK USP.png with size 1x1353
# Deleting unusually small image: data/without_signal/12794300_AFSK.png with size 2x1533
# Deleting unusually small image: data/without_signal/12776067_GMSK.png with size 1x1469
# Deleting unusually small image: data/without_signal/12827006_CW.png with size 1x1512
# Deleting unusually small image: data/without_signal/13008608_BPSK.png with size 1x1458
# Deleting unusually small image: data/without_signal/12844760_GFSK.png with size 3x1504
# Deleting unusually small image: data/without_signal/12916415_FM.png with size 1x1508
# Deleting unusually small image: data/without_signal/12955454_GMSK.png with size 1x1528
# Deleting unusually small image: data/without_signal/12945314_FM.png with size 1x1435
# Deleting unusually small image: data/without_signal/12981375_GMSK.png with size 3x1508
# Deleting unusually small image: data/without_signal/12908505_MSK AX.100 Mode 5.png with size 617x11
# Deleting unusually small image: data/without_signal/12766249_FM.png with size 1x1514
# Deleting unusually small image: data/without_signal/12763104_FM.png with size 1x1092
# Deleting unusually small image: data/without_signal/12784103_GMSK.png with size 4x1543
# Deleting unusually small image: data/without_signal/12979702_FM.png with size 1x1399
# Deleting unusually small image: data/without_signal/12781801_GMSK.png with size 4x1112
# Deleting unusually small image: data/without_signal/12979918_GMSK.png with size 38x1544
# Deleting unusually small image: data/without_signal/12773294_FM.png with size 3x1535
# Deleting unusually small image: data/without_signal/12944928_FM.png with size 3x1525
# Deleting unusually small image: data/without_signal/12838618_FM.png with size 3x1527
# Deleting unusually small image: data/without_signal/12775573_FM.png with size 1x1364
# Deleting unusually small image: data/without_signal/12839194_MSK AX.100 Mode 5.png with size 2x1525
# Deleting unusually small image: data/without_signal/12934306_FM.png with size 1x1526
# Deleting unusually small image: data/without_signal/12889857_GFSK.png with size 1x1538
# Deleting unusually small image: data/without_signal/12966439_BPSK.png with size 1x1506
# Deleting unusually small image: data/without_signal/12842609_BPSK.png with size 1x1523
# Deleting unusually small image: data/without_signal/12900308_GMSK.png with size 3x1543
# Deleting unusually small image: data/without_signal/12856786_FSK.png with size 3x1539
# Deleting unusually small image: data/without_signal/12951249_CW.png with size 2x1506
# Deleting unusually small image: data/without_signal/12846768_FM.png with size 1x1521
# Deleting unusually small image: data/without_signal/12884416_GMSK.png with size 3x1537
# Deleting unusually small image: data/without_signal/12995385_GMSK.png with size 7x1544
# Deleting unusually small image: data/without_signal/12909024_GMSK.png with size 2x1539
# Deleting unusually small image: data/without_signal/12760170_FM.png with size 2x1534
# Deleting unusually small image: data/without_signal/12796984_FSK.png with size 3x967
# Deleting unusually small image: data/without_signal/12801497_CW.png with size 1x1517
# Deleting unusually small image: data/without_signal/12792462_FM.png with size 4x1537
# Deleting unusually small image: data/without_signal/12765725_GMSK.png with size 1x1478
# Deleting unusually small image: data/without_signal/12807270_CW.png with size 1x1437
# Deleting unusually small image: data/without_signal/12976554_GMSK.png with size 3x66
# Deleting unusually small image: data/without_signal/12842801_GFSK.png with size 1x1520
# Deleting unusually small image: data/without_signal/12840338_FM.png with size 1x1430
# Deleting unusually small image: data/without_signal/12821290_GMSK.png with size 1x1460
# Deleting unusually small image: data/without_signal/12957431_GMSK.png with size 2x1533
# Deleting unusually small image: data/without_signal/12770291_FM.png with size 1x1329
# Deleting unusually small image: data/without_signal/12793876_SSTV.png with size 4x1531
# Deleting unusually small image: data/without_signal/12980030_FSK AX.100 Mode 5.png with size 2x1504
# Deleting unusually small image: data/without_signal/12835519_GFSK.png with size 1x1530
# Deleting unusually small image: data/without_signal/12988628_GFSK.png with size 1x1507
# Deleting unusually small image: data/without_signal/12981285_FSK AX.25 G3RUH.png with size 1x1388
# Deleting unusually small image: data/without_signal/12815006_FM.png with size 1x1262
# Deleting unusually small image: data/without_signal/12821731_FSK.png with size 1x1228
# Deleting unusually small image: data/without_signal/12774339_LoRa.png with size 2x1523
# Deleting unusually small image: data/without_signal/12907810_SSTV.png with size 3x1529
# Deleting unusually small image: data/without_signal/12823241_BPSK.png with size 1x1517
# Deleting unusually small image: data/without_signal/12912346_GFSK.png with size 2x1505
# Deleting unusually small image: data/without_signal/12897758_FM.png with size 2x1525
# Deleting unusually small image: data/without_signal/12924378_FM.png with size 18x1543
# Deleting unusually small image: data/without_signal/12784160_FSK.png with size 1x1527
# Deleting unusually small image: data/without_signal/12791345_FM.png with size 1x1354
# Deleting unusually small image: data/without_signal/12901365_FM.png with size 1x1466
# Deleting unusually small image: data/without_signal/12991581_GFSK.png with size 17x1539
# Deleting unusually small image: data/without_signal/12794958_CW.png with size 3x1531
# Deleting unusually small image: data/without_signal/12959814_GMSK.png with size 8x1543
# Deleting unusually small image: data/without_signal/12765612_GMSK.png with size 1x1498
# Deleting unusually small image: data/without_signal/12898612_FM.png with size 19x1544
# Deleting unusually small image: data/without_signal/12927552_LoRa.png with size 2x1537
# Deleting unusually small image: data/without_signal/12945331_FSK AX.100 Mode 5.png with size 1x1258
# Deleting unusually small image: data/without_signal/12989862_FM.png with size 9x1536
# Deleting unusually small image: data/without_signal/13004280_GMSK.png with size 1x1526
# Deleting unusually small image: data/without_signal/12784157_GMSK.png with size 8x1544
# Deleting unusually small image: data/without_signal/12993347_CW.png with size 2x1476
# Deleting unusually small image: data/without_signal/13030515_FSK AX.100 Mode 5.png with size 4x1541
# Deleting unusually small image: data/without_signal/12802597_GFSK.png with size 3x1451
# Deleting unusually small image: data/without_signal/12839008_AFSK.png with size 25x1542
# Deleting unusually small image: data/without_signal/12792698_CW.png with size 1x1527
# Deleting unusually small image: data/without_signal/12764846_FM.png with size 2x1527
# Deleting unusually small image: data/without_signal/12982112_FM.png with size 1x1504
# Deleting unusually small image: data/without_signal/12862316_GFSK.png with size 52x1544
# Deleting unusually small image: data/without_signal/12809593_GFSK.png with size 1x1522
# Deleting unusually small image: data/without_signal/12904174_BPSK.png with size 1x1174
# Deleting unusually small image: data/without_signal/12813789_BPSK.png with size 1x1495
# Deleting unusually small image: data/without_signal/12833954_FM.png with size 1x1533
# Deleting unusually small image: data/without_signal/12813124_GMSK.png with size 216x1087
# Deleting unusually small image: data/without_signal/12961989_GMSK.png with size 3x1522
# Deleting unusually small image: data/without_signal/12795981_AFSK TUBiX10.png with size 1x1435
# Deleting unusually small image: data/without_signal/12940264_FSK.png with size 3x1168
# Deleting unusually small image: data/without_signal/12859123_CW.png with size 9x1429
# Deleting unusually small image: data/without_signal/12869412_MSK.png with size 2x1481
# Deleting unusually small image: data/without_signal/12820018_FM.png with size 1x1474
# Deleting unusually small image: data/without_signal/13006503_DUV.png with size 598x254
# Deleting unusually small image: data/without_signal/12951081_AFSK TUBiX10.png with size 1x1492
# Deleting unusually small image: data/without_signal/12773292_GMSK.png with size 2x1534
# Deleting unusually small image: data/without_signal/12900716_GMSK.png with size 4x1541
# Deleting unusually small image: data/without_signal/12798481_FSK.png with size 6x1544
# Deleting unusually small image: data/without_signal/12782206_GMSK USP.png with size 1x64
# Deleting unusually small image: data/without_signal/12909171_FM.png with size 1x1505
# Deleting unusually small image: data/without_signal/12774332_LoRa.png with size 1x1372
# Deleting unusually small image: data/without_signal/12780597_FSK AX.25 G3RUH.png with size 1x1440
# Deleting unusually small image: data/without_signal/12834244_MSK AX.100 Mode 5.png with size 29x1544
# Deleting unusually small image: data/without_signal/12920754_FSK.png with size 4x1003
# Deleting unusually small image: data/without_signal/12866096_FSK.png with size 1x1373
# Deleting unusually small image: data/without_signal/13015166_SSTV.png with size 6x1525
# Deleting unusually small image: data/without_signal/12869390_BPSK.png with size 3x1505
# Deleting unusually small image: data/without_signal/12889240_BPSK.png with size 23x3
# Deleting unusually small image: data/without_signal/13015939_SSTV.png with size 6x1531
# Deleting unusually small image: data/without_signal/12795464_LRPT.png with size 1x1510
# Deleting unusually small image: data/without_signal/12832810_SSTV.png with size 3x1535
# Deleting unusually small image: data/without_signal/12869248_LRPT.png with size 13x1453
# Deleting unusually small image: data/without_signal/12812184_SSTV.png with size 8x1533
# Deleting unusually small image: data/without_signal/12784384_DUV.png with size 2x1494
# Deleting unusually small image: data/without_signal/12804377_SSTV.png with size 6x1345
# Deleting unusually small image: data/without_signal/12865829_FM.png with size 1x1356
# Deleting unusually small image: data/without_signal/12800000_DUV.png with size 5x1351
# Deleting unusually small image: data/without_signal/12989299_GFSK.png with size 2x1502
# Deleting unusually small image: data/without_signal/12816279_FSK.png with size 1x1104
# Deleting unusually small image: data/without_signal/12977707_FM.png with size 2x1501
# Deleting unusually small image: data/without_signal/12982527_SSTV.png with size 1x1525
# Deleting unusually small image: data/without_signal/12760718_FSK.png with size 1x1332
# Deleting unusually small image: data/without_signal/13001392_CW.png with size 16x1484
# Deleting unusually small image: data/without_signal/12809030_FSK AX.100 Mode 5.png with size 1x1517
# Deleting unusually small image: data/without_signal/13020545_GFSK.png with size 1x1483
# Deleting unusually small image: data/without_signal/12833991_FM.png with size 187x1537
# Deleting unusually small image: data/without_signal/12805760_BPSK.png with size 1x1514
# Deleting unusually small image: data/without_signal/12956598_FM.png with size 1x1423
# Deleting unusually small image: data/without_signal/12773291_FSK.png with size 3x1536
# Deleting unusually small image: data/without_signal/12834100_MSK AX.100 Mode 5.png with size 3x1534
# Deleting unusually small image: data/without_signal/12979683_BPSK.png with size 1x1378
# Deleting unusually small image: data/without_signal/12801692_BPSK.png with size 1x1434
# Deleting unusually small image: data/without_signal/12779816_CW.png with size 1x1513
# Deleting unusually small image: data/without_signal/12820645_FSK AX.100 Mode 5.png with size 1x1477
# Deleting unusually small image: data/without_signal/12819464_FM.png with size 3x1503
# Deleting unusually small image: data/without_signal/12785716_BPSK.png with size 2x1530
# Deleting unusually small image: data/without_signal/12826585_GMSK.png with size 1x1535
# Deleting unusually small image: data/without_signal/12813241_GMSK.png with size 21x1468
# Deleting unusually small image: data/without_signal/12799724_FM.png with size 13x1532
# Deleting unusually small image: data/without_signal/12760553_FM.png with size 617x1475
# Deleting unusually small image: data/without_signal/12995550_GMSK.png with size 5x80
# Deleting unusually small image: data/without_signal/12789703_FM.png with size 1x1521
# Deleting unusually small image: data/without_signal/12886596_GFSK.png with size 1x1462
# Deleting unusually small image: data/without_signal/12812185_BPSK.png with size 2x1455
# Deleting unusually small image: data/without_signal/12913089_FM.png with size 4x1443
# Deleting unusually small image: data/without_signal/12944465_FM.png with size 30x1544
# Deleting unusually small image: data/without_signal/12971276_AFSK TUBiX10.png with size 2x1498
# Deleting unusually small image: data/without_signal/12857105_SSTV.png with size 9x1507
# Deleting unusually small image: data/without_signal/12814389_AFSK TUBiX10.png with size 1x1533
# Deleting unusually small image: data/without_signal/12998998_SSTV.png with size 6x1531
# Deleting unusually small image: data/without_signal/12826285_FM.png with size 10x1534
# Deleting unusually small image: data/without_signal/12772824_FM.png with size 3x1468
# Deleting unusually small image: data/without_signal/12965838_GMSK.png with size 1x1419
# Deleting unusually small image: data/without_signal/12820184_FM.png with size 2x1449
# Deleting unusually small image: data/without_signal/13009908_FSK AX.100 Mode 5.png with size 1x1274
# Deleting unusually small image: data/without_signal/12995411_GMSK.png with size 174x1537
# Deleting unusually small image: data/without_signal/12775170_CW.png with size 1x1478
# Deleting unusually small image: data/without_signal/12882445_GMSK.png with size 214x1144
# Deleting unusually small image: data/without_signal/12903684_CW.png with size 1x1222
# Deleting unusually small image: data/without_signal/12829614_GMSK.png with size 392x1537
# Deleting unusually small image: data/without_signal/12796166_FM.png with size 1x1512
# Deleting unusually small image: data/without_signal/12798885_CW.png with size 1x1535
# Deleting unusually small image: data/without_signal/12843231_GFSK.png with size 1x1471
# Deleting unusually small image: data/without_signal/12758750_FM.png with size 2x1509
# Deleting unusually small image: data/without_signal/13006284_GMSK.png with size 4x1540
# Deleting unusually small image: data/without_signal/12807274_LRPT.png with size 1x1535
# Deleting unusually small image: data/without_signal/12832266_CW.png with size 1x1332
# Deleting unusually small image: data/without_signal/12766571_FM.png with size 1x1467
# Deleting unusually small image: data/without_signal/12823662_FM.png with size 1x1515
# Deleting unusually small image: data/without_signal/12802384_FSK.png with size 8x1544
# Deleting unusually small image: data/without_signal/12770976_BPSK.png with size 2x1528
# Deleting unusually small image: data/without_signal/12999307_GMSK.png with size 1x1436
# Deleting unusually small image: data/without_signal/12986616_GMSK.png with size 1x1529
# Deleting unusually small image: data/without_signal/12792937_GMSK.png with size 1x1498
# Deleting unusually small image: data/without_signal/13004812_GMSK.png with size 14x1544
# Deleting unusually small image: data/without_signal/12793593_AFSK TUBiX10.png with size 1x1523
# Deleting unusually small image: data/without_signal/13008874_CW.png with size 2x1514
# Deleting unusually small image: data/without_signal/12809603_FM.png with size 1x1452
# Deleting unusually small image: data/without_signal/12920883_FSK.png with size 5x1430
# Deleting unusually small image: data/without_signal/13012204_MSK AX.100 Mode 5.png with size 1x1303
# Deleting unusually small image: data/without_signal/12857246_FM.png with size 3x1403
# Deleting unusually small image: data/without_signal/12860412_GFSK.png with size 2x1490
# Deleting unusually small image: data/without_signal/12766572_FSK.png with size 3x1510
# Deleting unusually small image: data/without_signal/12865981_CW.png with size 2x1526
# Deleting unusually small image: data/without_signal/12896208_BPSK.png with size 1x1440
# Deleting unusually small image: data/without_signal/12848632_GMSK.png with size 2x1484
# Deleting unusually small image: data/without_signal/12816841_FM.png with size 5x1507
# Deleting unusually small image: data/without_signal/13007613_DUV.png with size 1x774
# Deleting unusually small image: data/without_signal/12782035_QPSK.png with size 2x1523
# Deleting unusually small image: data/without_signal/12834089_MSK AX.100 Mode 5.png with size 18x1544
# Deleting unusually small image: data/without_signal/13009515_CW.png with size 1x1396
# Deleting unusually small image: data/without_signal/12941344_FM.png with size 1x1485
# Deleting unusually small image: data/without_signal/12954153_FM.png with size 1x1507
# Deleting unusually small image: data/without_signal/12856815_AFSK.png with size 32x1541
# Deleting unusually small image: data/without_signal/12868065_FM.png with size 2x1457
# Deleting unusually small image: data/without_signal/12834013_MSK AX.100 Mode 5.png with size 92x1537
# Deleting unusually small image: data/without_signal/12799366_CW.png with size 1x1489
# Deleting unusually small image: data/without_signal/12982143_FM.png with size 11x1538
# Deleting unusually small image: data/without_signal/12981247_GFSK.png with size 1x1506
# Deleting unusually small image: data/without_signal/12892213_GMSK.png with size 30x1137
# Deleting unusually small image: data/without_signal/12815225_LRPT.png with size 3x1537
# Deleting unusually small image: data/without_signal/12923819_FSK.png with size 1x1417
# Deleting unusually small image: data/without_signal/12949877_BPSK.png with size 1x1382
# Deleting unusually small image: data/without_signal/12967699_LoRa.png with size 13x1544
# Deleting unusually small image: data/without_signal/12981729_CW.png with size 3x1537
# Deleting unusually small image: data/without_signal/12993534_LRPT.png with size 7x1500
# Deleting unusually small image: data/without_signal/12976602_GMSK.png with size 4x1531
# Deleting unusually small image: data/without_signal/12821901_FSK.png with size 1x1476
# Deleting unusually small image: data/without_signal/12946682_FM.png with size 2x1489
# Deleting unusually small image: data/without_signal/12988516_GMSK.png with size 5x1518
# Deleting unusually small image: data/without_signal/12961053_FM.png with size 2x1527
# Deleting unusually small image: data/without_signal/12875271_WSJT.png with size 1x1363
# Deleting unusually small image: data/without_signal/12791575_BPSK.png with size 1x1441
# Deleting unusually small image: data/without_signal/12778621_FSK.png with size 3x1528
# Deleting unusually small image: data/without_signal/12769417_SSTV.png with size 617x110
# Deleting unusually small image: data/without_signal/12939636_FSK.png with size 3x1338
# Deleting unusually small image: data/without_signal/12782076_GMSK.png with size 1x1506
# Deleting unusually small image: data/without_signal/12866422_FSK.png with size 2x1286
# Deleting unusually small image: data/without_signal/12933697_CW.png with size 1x1469
# Deleting unusually small image: data/without_signal/12866387_BPSK.png with size 13x1543
# Deleting unusually small image: data/without_signal/12994031_BPSK.png with size 3x1525
# Deleting unusually small image: data/without_signal/12858082_LRPT.png with size 1x1468
# Deleting unusually small image: data/without_signal/12784841_CW.png with size 2x1525
# Deleting unusually small image: data/without_signal/12844816_GFSK.png with size 3x1226
# Deleting unusually small image: data/without_signal/12982962_CW.png with size 3x1512
# Deleting unusually small image: data/without_signal/12951085_FSK.png with size 1x1527
# Deleting unusually small image: data/without_signal/12780991_FSK AX.25 G3RUH.png with size 4x1189
# Deleting unusually small image: data/without_signal/12904946_CW.png with size 6x1351
# Deleting unusually small image: data/without_signal/12832184_CW.png with size 1x1520
# Deleting unusually small image: data/without_signal/12913343_GFSK.png with size 1x1275
# Deleting unusually small image: data/without_signal/12996702_FSK AX.100 Mode 5.png with size 1x1494
# Deleting unusually small image: data/without_signal/12797848_LoRa.png with size 1x1508
# Deleting unusually small image: data/without_signal/12905959_FSK AX.100 Mode 5.png with size 1x1483
# Deleting unusually small image: data/without_signal/12899272_CW.png with size 1x1439
# Deleting unusually small image: data/without_signal/12803913_SSTV.png with size 3x1525
# Deleting unusually small image: data/without_signal/12781927_GMSK.png with size 3x1495
# Deleting unusually small image: data/without_signal/12781923_BPSK.png with size 3x1518
# Deleting unusually small image: data/without_signal/12870086_FSK.png with size 1x1011
# Deleting unusually small image: data/without_signal/12795276_USB.png with size 1x1502
# Deleting unusually small image: data/without_signal/12930289_CW.png with size 5x1500
# Deleting unusually small image: data/without_signal/12967968_FM.png with size 1x1396
# Deleting unusually small image: data/without_signal/12929662_GFSK.png with size 1x1537
# Deleting unusually small image: data/without_signal/12924374_GMSK.png with size 6x1543
# Deleting unusually small image: data/without_signal/12765507_GMSK.png with size 3x1508
# Deleting unusually small image: data/without_signal/12904816_AFSK TUBiX10.png with size 2x1529
# Deleting unusually small image: data/without_signal/12977744_FM.png with size 2x1502
# Deleting unusually small image: data/without_signal/12872719_GFSK.png with size 5x1537
# Deleting unusually small image: data/without_signal/12897793_CW.png with size 6x1520
# Deleting unusually small image: data/without_signal/13016203_BPSK.png with size 6x1543
# Deleting unusually small image: data/without_signal/12983389_CW.png with size 1x1198
# Deleting unusually small image: data/without_signal/12908309_SSTV.png with size 7x1524
# Deleting unusually small image: data/without_signal/12784128_BPSK.png with size 4x1542
# Deleting unusually small image: data/without_signal/12809473_GFSK.png with size 2x1540
# Deleting unusually small image: data/without_signal/12862034_FM.png with size 1x1473
# Deleting unusually small image: data/without_signal/12985175_GFSK.png with size 2x1513
# Deleting unusually small image: data/without_signal/12778603_GFSK.png with size 4x1530
# Deleting unusually small image: data/without_signal/12819716_FSK.png with size 6x1544
# Deleting unusually small image: data/without_signal/13015375_GMSK.png with size 3x1482
# Deleting unusually small image: data/without_signal/12888467_FM.png with size 1x1532
# Deleting unusually small image: data/without_signal/12920629_DUV.png with size 2x1507
# Deleting unusually small image: data/without_signal/12853617_FM.png with size 10x1544
# Deleting unusually small image: data/without_signal/12873608_BPSK.png with size 1x1529
# Deleting unusually small image: data/without_signal/12800269_FSK.png with size 1x1516
# Deleting unusually small image: data/without_signal/12858901_QPSK.png with size 3x1517
# Deleting unusually small image: data/without_signal/12897781_CW.png with size 1x1480
# Deleting unusually small image: data/without_signal/12994011_CW.png with size 8x1494
# Deleting unusually small image: data/without_signal/12913383_LRPT.png with size 3x1521
# Deleting unusually small image: data/without_signal/12802635_BPSK.png with size 2x1528
# Deleting unusually small image: data/without_signal/12874556_USB.png with size 1x1471
# Deleting unusually small image: data/without_signal/12888685_FSK.png with size 2x1464
# Deleting unusually small image: data/without_signal/12769817_FM.png with size 1x1531
# Deleting unusually small image: data/without_signal/12988675_FM.png with size 1x1507
# Deleting unusually small image: data/without_signal/12807834_FSK.png with size 10x1544
# Deleting unusually small image: data/without_signal/12781922_USB.png with size 1x1517
# Deleting unusually small image: data/without_signal/12834063_MSK AX.100 Mode 5.png with size 15x1544
# Deleting unusually small image: data/without_signal/12766157_GMSK.png with size 1x1427
# Deleting unusually small image: data/without_signal/12957271_GMSK.png with size 1x1472
# Deleting unusually small image: data/without_signal/12759475_FM.png with size 1x1527
# Deleting unusually small image: data/without_signal/12977489_GMSK.png with size 254x1537
# Deleting unusually small image: data/without_signal/12881139_LoRa.png with size 8x1543
# Deleting unusually small image: data/without_signal/12885367_BPSK.png with size 1x1514
# Deleting unusually small image: data/without_signal/12899315_GMSK.png with size 1x1530
# Deleting unusually small image: data/without_signal/12982690_GMSK.png with size 3x1544
# Deleting unusually small image: data/without_signal/12779625_BPSK.png with size 2x1536
# Deleting unusually small image: data/without_signal/12931171_GFSK.png with size 20x26
# Deleting unusually small image: data/without_signal/12760099_FM.png with size 1x1493
# Deleting unusually small image: data/without_signal/12771757_GMSK.png with size 2x1504
# Deleting unusually small image: data/without_signal/12823802_AFSK.png with size 16x1544
# Deleting unusually small image: data/without_signal/12778434_CW.png with size 1x1519
# Deleting unusually small image: data/without_signal/12991596_FSK AX.100 Mode 5.png with size 2x1543
# Deleting unusually small image: data/without_signal/12840097_LRPT.png with size 6x1470
# Deleting unusually small image: data/without_signal/12786108_CW.png with size 1x1250
# Deleting unusually small image: data/without_signal/12997946_FM.png with size 1x1505
# Deleting unusually small image: data/without_signal/12868263_GFSK.png with size 1x1456
# Deleting unusually small image: data/without_signal/12778573_GMSK.png with size 7x1527
# Deleting unusually small image: data/without_signal/12831645_GMSK.png with size 1x1452
# Deleting unusually small image: data/without_signal/12872727_GFSK.png with size 21x1537
# Deleting unusually small image: data/without_signal/12837040_FSK AX.100 Mode 5.png with size 1x1448
# Deleting unusually small image: data/without_signal/12949042_FM.png with size 8x1537
# Deleting unusually small image: data/without_signal/12838357_BPSK.png with size 1x1470
# Deleting unusually small image: data/without_signal/12830935_GFSK.png with size 617x577
# Deleting unusually small image: data/without_signal/12981404_FM.png with size 2x1492
# Deleting unusually small image: data/without_signal/12966534_BPSK PMT-A3.png with size 30x1544
# Deleting unusually small image: data/without_signal/12867004_BPSK.png with size 1x1497
# Deleting unusually small image: data/without_signal/12824304_GFSK.png with size 1x1358
# Deleting unusually small image: data/without_signal/12983174_FSK AX.100 Mode 5.png with size 1x1480
# Deleting unusually small image: data/without_signal/12941150_GMSK.png with size 1x1527
# Deleting unusually small image: data/without_signal/12777143_GMSK.png with size 1x1377
# Deleting unusually small image: data/without_signal/12784119_FSK.png with size 5x1526
# Deleting unusually small image: data/without_signal/12913773_LRPT.png with size 1x1502
# Deleting unusually small image: data/without_signal/12891716_GFSK.png with size 5x1280
# Deleting unusually small image: data/without_signal/12799022_CW.png with size 1x1388
# Deleting unusually small image: data/without_signal/12800385_FM.png with size 1x1497
# Deleting unusually small image: data/without_signal/12846390_GMSK.png with size 250x1353
# Deleting unusually small image: data/without_signal/12835330_GMSK.png with size 375x1385
# Deleting unusually small image: data/without_signal/12839021_GFSK.png with size 2x1543
# Deleting unusually small image: data/without_signal/12973297_BPSK.png with size 1x1500
# Deleting unusually small image: data/without_signal/13014599_LRPT.png with size 17x1456
# Deleting unusually small image: data/without_signal/12771839_FM.png with size 1x1498
# Deleting unusually small image: data/without_signal/12829845_FM.png with size 1x1507
# Deleting unusually small image: data/without_signal/12772798_FSK.png with size 3x1504
# Deleting unusually small image: data/without_signal/12835253_GMSK.png with size 18x678
# Deleting unusually small image: data/without_signal/12977530_GMSK.png with size 2x1449
# Deleting unusually small image: data/without_signal/12837600_GMSK.png with size 2x1481
# Deleting unusually small image: data/without_signal/12795143_FM.png with size 2x1514
# Deleting unusually small image: data/without_signal/12818810_GMSK.png with size 39x1128
# Deleting unusually small image: data/without_signal/12885101_FM.png with size 1x1359
# Deleting unusually small image: data/without_signal/12837131_FSK AX.100 Mode 5.png with size 1x1487
# Deleting unusually small image: data/without_signal/12821141_FM.png with size 1x1507
# Deleting unusually small image: data/without_signal/12816238_CW.png with size 2x1536
# Deleting unusually small image: data/without_signal/13006521_GFSK.png with size 3x1435
# Deleting unusually small image: data/without_signal/12849974_GMSK.png with size 1x1498
# Deleting unusually small image: data/without_signal/12772070_BPSK.png with size 2x1489
# Deleting unusually small image: data/without_signal/13016779_CW.png with size 24x1544
# Deleting unusually small image: data/without_signal/13011777_FM.png with size 3x1523
# Deleting unusually small image: data/without_signal/12853963_FM.png with size 30x1544
# Deleting unusually small image: data/without_signal/12812305_LoRa.png with size 1x1477
# Deleting unusually small image: data/without_signal/12798553_FSK.png with size 3x1462
# Deleting unusually small image: data/without_signal/12827435_DUV.png with size 1x1472
# Deleting unusually small image: data/without_signal/12916468_FSK AX.100 Mode 5.png with size 1x1415
# Deleting unusually small image: data/without_signal/12952955_FSK.png with size 1x1431
# Deleting unusually small image: data/without_signal/12941161_FM.png with size 1x1478
# Deleting unusually small image: data/without_signal/12886750_FSK.png with size 1x1302
# Deleting unusually small image: data/without_signal/12849714_AFSK.png with size 1x1344
# Deleting unusually small image: data/without_signal/13022278_CW.png with size 1x1253
# Deleting unusually small image: data/without_signal/12900523_GMSK.png with size 5x1544
# Deleting unusually small image: data/without_signal/12952645_FM.png with size 1x1456
# Deleting unusually small image: data/without_signal/12819381_LRPT.png with size 19x1381
# Deleting unusually small image: data/without_signal/12877453_AFSK.png with size 1x1410
# Deleting unusually small image: data/without_signal/12812637_FSK AX.100 Mode 5.png with size 3x1537
# Deleting unusually small image: data/without_signal/12840294_FM.png with size 1x1504
# Deleting unusually small image: data/without_signal/12898598_BPSK.png with size 26x1542
# Deleting unusually small image: data/without_signal/12846130_GMSK.png with size 112x979
# Deleting unusually small image: data/without_signal/12800654_GMSK.png with size 2x1450
# Deleting unusually small image: data/without_signal/13006787_BPSK.png with size 1x1433
# Deleting unusually small image: data/without_signal/12773708_AFSK.png with size 2x1502
# Deleting unusually small image: data/without_signal/12902067_GFSK.png with size 170x1536
# Deleting unusually small image: data/without_signal/12837351_SSTV.png with size 521x32
# Deleting unusually small image: data/without_signal/12905702_CW.png with size 1x7
# Deleting unusually small image: data/without_signal/12945458_USB.png with size 4x1536
# Deleting unusually small image: data/without_signal/12870444_CW.png with size 1x1513
# Deleting unusually small image: data/without_signal/12982144_GFSK.png with size 9x1543
# Deleting unusually small image: data/without_signal/12997589_FM.png with size 1x1527
# Deleting unusually small image: data/without_signal/12843384_FSK.png with size 1x1272
# Deleting unusually small image: data/without_signal/12981406_FM.png with size 2x1533
# Deleting unusually small image: data/without_signal/12850246_FSK.png with size 1x1350
# Deleting unusually small image: data/without_signal/12773282_GMSK.png with size 3x1489
# Deleting unusually small image: data/without_signal/12990073_CW.png with size 16x1525
# Deleting unusually small image: data/without_signal/12831290_CW.png with size 7x1532
# Deleting unusually small image: data/without_signal/12763202_SSTV.png with size 483x2
# Deleting unusually small image: data/without_signal/12850389_FM.png with size 1x1525
# Deleting unusually small image: data/without_signal/12805741_GMSK.png with size 1x1336
# Deleting unusually small image: data/without_signal/12843679_FM.png with size 2x1499
# Deleting unusually small image: data/without_signal/12980536_GMSK.png with size 2x1456
# Deleting unusually small image: data/without_signal/12982458_FM.png with size 3x5
# Deleting unusually small image: data/without_signal/13008236_FSK.png with size 1x1302
# Deleting unusually small image: data/without_signal/12906123_BPSK.png with size 3x1535
# Deleting unusually small image: data/without_signal/12880548_FM.png with size 3x1434
# Deleting unusually small image: data/without_signal/12845566_FM.png with size 369x1537
# Deleting unusually small image: data/without_signal/13043201_GFSK.png with size 1x153
# Deleting unusually small image: data/without_signal/12874671_BPSK.png with size 1x1537
# Deleting unusually small image: data/without_signal/12853955_FM.png with size 181x1537
# Deleting unusually small image: data/without_signal/12772251_GMSK.png with size 1x1440
# Deleting unusually small image: data/without_signal/12783814_FM.png with size 1x1513
# Deleting unusually small image: data/without_signal/12943131_LRPT.png with size 1x1435
# Deleting unusually small image: data/without_signal/12970647_GMSK.png with size 1x1472
# Deleting unusually small image: data/without_signal/12795433_CW.png with size 2x1511
# Deleting unusually small image: data/without_signal/12979968_GMSK.png with size 220x1537
# Deleting unusually small image: data/without_signal/12847082_GFSK.png with size 13x1543
# Deleting unusually small image: data/without_signal/12915677_BPSK.png with size 1x1403
# Deleting unusually small image: data/without_signal/12965144_FSK AX.100 Mode 5.png with size 1x1505
# Deleting unusually small image: data/without_signal/12826313_FM.png with size 124x1537
# Deleting unusually small image: data/without_signal/12798450_GMSK.png with size 4x1543
# Deleting unusually small image: data/without_signal/12818162_FSK.png with size 3x1490
# Deleting unusually small image: data/without_signal/12793944_CW.png with size 1x1533
# Deleting unusually small image: data/without_signal/12815155_FM.png with size 1x1522
# Deleting unusually small image: data/without_signal/13012126_FSK.png with size 2x1497
# Deleting unusually small image: data/without_signal/13004236_GMSK.png with size 2x69
# Deleting unusually small image: data/without_signal/12984885_FM.png with size 2x1533
# Deleting unusually small image: data/without_signal/12764722_CW.png with size 1x1518
# Deleting unusually small image: data/without_signal/12803894_CW.png with size 1x1490
# Deleting unusually small image: data/without_signal/12834162_MSK AX.100 Mode 5.png with size 173x1537
# Deleting unusually small image: data/without_signal/12875185_FM.png with size 1x1469
# Deleting unusually small image: data/without_signal/12866492_GMSK.png with size 2x1525
# Deleting unusually small image: data/without_signal/12777850_CW.png with size 2x1489
# Deleting unusually small image: data/without_signal/12970345_FM.png with size 3x1504
# Deleting unusually small image: data/without_signal/12845413_FSK AX.100 Mode 5.png with size 7x14
# Deleting unusually small image: data/without_signal/12898985_FSK.png with size 1x1465
# Deleting unusually small image: data/without_signal/12898396_BPSK.png with size 3x1524
# Deleting unusually small image: data/without_signal/12989285_FM.png with size 2x1521
# Deleting unusually small image: data/without_signal/12814100_MSK AX.100 Mode 5.png with size 2x1515
# Deleting unusually small image: data/without_signal/12893324_GFSK.png with size 189x1537
# Deleting unusually small image: data/without_signal/13000394_FM.png with size 2x1532
# Deleting unusually small image: data/without_signal/12925034_BPSK.png with size 1x1514
# Deleting unusually small image: data/without_signal/13000560_AFSK TUBiX10.png with size 3x1514
# Deleting unusually small image: data/without_signal/12856781_AFSK.png with size 11x1544
# Deleting unusually small image: data/without_signal/13011342_GMSK.png with size 1x1378
# Deleting unusually small image: data/without_signal/12819355_USB.png with size 2x1533
# Deleting unusually small image: data/without_signal/12898593_SSTV.png with size 3x1532
# Deleting unusually small image: data/without_signal/13019235_GMSK.png with size 243x1537
# Deleting unusually small image: data/without_signal/12821638_FSK.png with size 1x1226
# Deleting unusually small image: data/without_signal/12875351_FM.png with size 2x1510
# Deleting unusually small image: data/without_signal/12817514_FM.png with size 2x1489
# Deleting unusually small image: data/without_signal/12830074_GFSK.png with size 2x1540
# Deleting unusually small image: data/without_signal/12833712_FSK AX.100 Mode 5.png with size 2x1535
# Deleting unusually small image: data/without_signal/13000135_SSTV.png with size 5x1531
# Deleting unusually small image: data/without_signal/12962680_BPSK.png with size 1x1465
# Deleting unusually small image: data/without_signal/12932627_CW.png with size 21x1528
# Deleting unusually small image: data/without_signal/12807829_GMSK.png with size 6x1544
# Deleting unusually small image: data/without_signal/12944510_FSK.png with size 1x1076
# Deleting unusually small image: data/without_signal/12770614_CW.png with size 6x1529
# Deleting unusually small image: data/without_signal/12827576_BPSK.png with size 3x1521
# Deleting unusually small image: data/without_signal/12871545_GMSK.png with size 81x1119
# Deleting unusually small image: data/without_signal/13020414_FM.png with size 1x1478
# Deleting unusually small image: data/without_signal/12901610_LoRa.png with size 305x1537
# Deleting unusually small image: data/without_signal/13008347_FSK.png with size 1x1510
# Deleting unusually small image: data/without_signal/12833964_FM.png with size 2x1537
# Deleting unusually small image: data/without_signal/12850313_CW.png with size 1x1519
# Deleting unusually small image: data/without_signal/12807315_CW.png with size 1x1530
# Deleting unusually small image: data/without_signal/12805042_CW.png with size 4x884
# Deleting unusually small image: data/without_signal/12996532_FSK.png with size 1x1365
# Deleting unusually small image: data/without_signal/12823674_GMSK.png with size 1x1529
# Deleting unusually small image: data/without_signal/12825206_FM.png with size 1x1500
# ...
# Deleting unusually small image: data/without_signal/12971039_LoRa.png with size 1x1469
# Deleting unusually small image: data/without_signal/12780053_GMSK USP.png with size 1x1081
# Deleting unusually small image: data/without_signal/12915800_SSTV.png with size 8x1526
# Deleting unusually small image: data/without_signal/12998354_CW.png with size 2x7
# Deleting unusually small image: data/without_signal/12760923_CW.png with size 1x1519
# Deleting unusually small image: data/without_signal/13007833_FM.png with size 1x1460
# Deleting unusually small image: data/without_signal/12889861_GFSK.png with size 9x1541
# Deleting unusually small image: data/without_signal/12772452_FM.png with size 1x1507
# Deleting unusually small image: data/without_signal/12863290_FM.png with size 1x1474
# Deleting unusually small image: data/without_signal/12972396_FM.png with size 2x1497
# Deleting unusually small image: data/without_signal/12972664_CW.png with size 1x1506
# Deleting unusually small image: data/without_signal/13010521_GMSK.png with size 5x1520
# Deleting unusually small image: data/without_signal/12760968_USB.png with size 2x1531
# Deleting unusually small image: data/without_signal/12889755_BPSK.png with size 15x944
# Deleting unusually small image: data/without_signal/12781916_CW.png with size 6x1513
# Deleting unusually small image: data/without_signal/12858840_FM.png with size 3x1481
# Deleting unusually small image: data/without_signal/12820168_WSJT.png with size 2x1366
# Deleting unusually small image: data/without_signal/12893118_FSK AX.25 G3RUH.png with size 1x1511
# Deleting unusually small image: data/without_signal/12806327_FSK.png with size 2x1529
# Deleting unusually small image: data/without_signal/12838199_LRPT.png with size 2x1518
# Deleting unusually small image: data/without_signal/12770747_LoRa.png with size 1x1463
# Deleting unusually small image: data/without_signal/12771916_FM.png with size 1x1445
# Deleting unusually small image: data/without_signal/12845770_MSK AX.100 Mode 5.png with size 198x1537
# Deleting unusually small image: data/without_signal/12971138_GFSK.png with size 2x1526
# Deleting unusually small image: data/without_signal/12773012_GMSK.png with size 1x1544
# Deleting unusually small image: data/without_signal/12889862_FM.png with size 20x1544
# Deleting unusually small image: data/without_signal/12983662_FM.png with size 2x1488
# Deleting unusually small image: data/without_signal/12758868_FSK.png with size 1x1256
# Deleting unusually small image: data/without_signal/12979855_FSK AX.100 Mode 5.png with size 1x1507
# Deleting unusually small image: data/without_signal/12812439_GMSK.png with size 3x1417
# Deleting unusually small image: data/without_signal/12816231_CW.png with size 3x1526
# Deleting unusually small image: data/without_signal/12773427_GFSK.png with size 4x841
# Deleting unusually small image: data/without_signal/12781895_FSK.png with size 2x1531
# Deleting unusually small image: data/without_signal/13014891_FM.png with size 3x1412
# Deleting unusually small image: data/without_signal/12932908_BPSK.png with size 1x1474
# Deleting unusually small image: data/without_signal/12973150_CW.png with size 1x1499
# Deleting unusually small image: data/without_signal/12868949_CERTO.png with size 10x1535
# Deleting unusually small image: data/without_signal/12772129_UNKNWN.png with size 10x1362
# Deleting unusually small image: data/without_signal/12785721_AFSK.png with size 5x1313
# Deleting unusually small image: data/without_signal/12829596_GMSK.png with size 5x1544
# Deleting unusually small image: data/without_signal/12971170_GFSK.png with size 1x1457
# Deleting unusually small image: data/without_signal/12828227_FM.png with size 2x1527
# Deleting unusually small image: data/without_signal/12890521_FM.png with size 3x4
# Deleting unusually small image: data/without_signal/12974277_FSK.png with size 3x1485
# Deleting unusually small image: data/without_signal/12832398_FM.png with size 1x1516
# Deleting unusually small image: data/without_signal/12944474_FM.png with size 21x1544
# Deleting unusually small image: data/without_signal/12788734_SSTV.png with size 617x1322
# Deleting unusually small image: data/without_signal/12921583_BPSK.png with size 14x168
# Deleting unusually small image: data/without_signal/12838940_FSK.png with size 4x1544
# Deleting unusually small image: data/without_signal/13008237_LRPT.png with size 1x1496
# Deleting unusually small image: data/without_signal/12983924_LRPT.png with size 1x1508
# Deleting unusually small image: data/without_signal/12868493_GMSK.png with size 1x1434
# Deleting unusually small image: data/without_signal/12782657_FM.png with size 3x1449
# Deleting unusually small image: data/without_signal/12781896_FSK AX.25 G3RUH.png with size 1x1523
# Deleting unusually small image: data/without_signal/12911854_MSK AX.100 Mode 5.png with size 1x1505
# Deleting unusually small image: data/without_signal/12892393_GFSK.png with size 14x1544
# Deleting unusually small image: data/without_signal/12802322_GMSK.png with size 2x1543
# Deleting unusually small image: data/without_signal/12796016_FSK AX.25 G3RUH.png with size 2x1495
# Deleting unusually small image: data/without_signal/12831213_AFSK.png with size 4x859
# Deleting unusually small image: data/without_signal/12924662_SSTV.png with size 2x1531
# Deleting unusually small image: data/without_signal/12839869_FM.png with size 1x1530
# Deleting unusually small image: data/without_signal/12950672_FSK.png with size 1x1442
# Deleting unusually small image: data/without_signal/12839969_FM.png with size 14x2
# Deleting unusually small image: data/without_signal/12852523_FM.png with size 2x1537
# Deleting unusually small image: data/without_signal/12816991_FM.png with size 2x1511
# Deleting unusually small image: data/without_signal/12802320_FSK AX.100 Mode 5.png with size 12x1544
# Deleting unusually small image: data/without_signal/12834657_GMSK.png with size 1x1535
# Deleting unusually small image: data/without_signal/12855550_CW.png with size 1x1473
# Deleting unusually small image: data/without_signal/12965574_FM.png with size 1x1360
# Deleting unusually small image: data/without_signal/12775416_GMSK.png with size 3x1542
# Deleting unusually small image: data/without_signal/12980478_LoRa.png with size 1x1492
# Deleting unusually small image: data/without_signal/12979233_FSK.png with size 3x1490
# Deleting unusually small image: data/without_signal/12800179_FSK.png with size 1x1368
# Deleting unusually small image: data/without_signal/12798569_FM.png with size 1x1360
# Deleting unusually small image: data/without_signal/12784154_GMSK.png with size 2x1542
# Deleting unusually small image: data/without_signal/12795621_FM.png with size 1x1486
# Deleting unusually small image: data/without_signal/12784155_GMSK.png with size 4x1544
# Deleting unusually small image: data/without_signal/12759509_CW.png with size 2x1478
# Deleting unusually small image: data/without_signal/12774340_CW.png with size 1x1445
# Deleting unusually small image: data/without_signal/12940573_BPSK.png with size 1x1486
# Deleting unusually small image: data/without_signal/12823673_FSK.png with size 2x1477
# Deleting unusually small image: data/without_signal/13004258_GMSK.png with size 4x1534
# Deleting unusually small image: data/without_signal/12934948_LoRa.png with size 1x1353
# Deleting unusually small image: data/without_signal/12781909_FSK.png with size 2x1533
# Deleting unusually small image: data/without_signal/12853829_GFSK.png with size 23x1537
# Deleting unusually small image: data/without_signal/13020901_FSK.png with size 1x1219
# Deleting unusually small image: data/without_signal/12797335_FM.png with size 3x1420
# Deleting unusually small image: data/without_signal/12897544_QPSK.png with size 2x1524
# Deleting unusually small image: data/without_signal/12834008_MSK AX.100 Mode 5.png with size 1x632
# Deleting unusually small image: data/without_signal/12921422_GMSK.png with size 1x630
# Deleting unusually small image: data/without_signal/12988398_FM.png with size 2x1504
# Deleting unusually small image: data/without_signal/12772279_LRPT.png with size 1x1531
# Deleting unusually small image: data/without_signal/12913511_BPSK.png with size 1x1512
# Deleting unusually small image: data/without_signal/12997602_FSK AX.100 Mode 5.png with size 1x1264
# Deleting unusually small image: data/without_signal/12769774_FM.png with size 1x1489
# Deleting unusually small image: data/without_signal/13019958_FSK.png with size 1x1499
# Deleting unusually small image: data/without_signal/13043338_GFSK.png with size 2x1506
# Deleting unusually small image: data/without_signal/12919892_BPSK.png with size 1x1465
# Deleting unusually small image: data/without_signal/12839013_CW.png with size 8x1544
# Deleting unusually small image: data/without_signal/12915519_GMSK.png with size 3x1410
# Deleting unusually small image: data/without_signal/12781615_BPSK.png with size 1x1512
# Deleting unusually small image: data/without_signal/12858933_FM.png with size 1x1481
# Deleting unusually small image: data/without_signal/12816541_BPSK.png with size 1x1543
# Deleting unusually small image: data/without_signal/12843582_FM.png with size 4x1295
# Deleting unusually small image: data/without_signal/13013690_FM.png with size 2x1497
# Deleting unusually small image: data/without_signal/12980601_GFSK.png with size 1x1414
# Deleting unusually small image: data/without_signal/12807813_GMSK.png with size 2x1544
# Deleting unusually small image: data/without_signal/12847087_GFSK.png with size 37x1537
# Deleting unusually small image: data/without_signal/12766258_BPSK.png with size 1x1535
# Deleting unusually small image: data/without_signal/12971040_BPSK.png with size 2x1534
# Deleting unusually small image: data/without_signal/12898432_CW.png with size 3x1468
# Deleting unusually small image: data/without_signal/12822626_FM.png with size 2x1511
# Deleting unusually small image: data/without_signal/12853671_FM.png with size 2x1536
# Deleting unusually small image: data/without_signal/12776031_CW.png with size 4x1493
# Deleting unusually small image: data/without_signal/13001220_LRPT.png with size 2x1524
# Deleting unusually small image: data/without_signal/12823679_FSK AX.25 G3RUH.png with size 8x1544
# Deleting unusually small image: data/without_signal/12969599_BPSK.png with size 2x1522
# Deleting unusually small image: data/without_signal/12777272_FSK AX.100 Mode 5.png with size 4x1466
# Deleting unusually small image: data/without_signal/12818424_FSK AX.100 Mode 5.png with size 242x1537
# Deleting unusually small image: data/without_signal/12902057_GFSK.png with size 20x1544
# Deleting unusually small image: data/without_signal/12882426_GMSK.png with size 190x245
# Deleting unusually small image: data/without_signal/12895418_BPSK.png with size 2x1476
# Deleting unusually small image: data/without_signal/12790347_FSK.png with size 1x788
# Deleting unusually small image: data/without_signal/12858842_FM.png with size 2x1497
# Deleting unusually small image: data/without_signal/12772672_USB.png with size 1x1405
# Deleting unusually small image: data/without_signal/12843446_LRPT.png with size 1x1533
# Deleting unusually small image: data/without_signal/12979532_CW.png with size 2x1533
# Deleting unusually small image: data/without_signal/13017321_GMSK.png with size 5x1543
# Deleting unusually small image: data/without_signal/12944164_BPSK.png with size 1x1450
# Deleting unusually small image: data/without_signal/12946067_GMSK.png with size 236x1537
# Deleting unusually small image: data/without_signal/12865971_SSTV.png with size 2x1536
# Deleting unusually small image: data/without_signal/12884259_LoRa.png with size 5x1535
# Deleting unusually small image: data/without_signal/12867189_GMSK.png with size 1x1495
# Deleting unusually small image: data/without_signal/12828485_AFSK.png with size 1x1459
# Deleting unusually small image: data/without_signal/12766145_FM.png with size 2x1502
# Deleting unusually small image: data/without_signal/12844846_GFSK.png with size 17x1348
# Deleting unusually small image: data/without_signal/12840022_SSTV.png with size 4x1534
# Deleting unusually small image: data/without_signal/12801087_GMSK.png with size 1x1457
# Deleting unusually small image: data/without_signal/12834207_MSK AX.100 Mode 5.png with size 12x1544
# Deleting unusually small image: data/without_signal/12834743_GMSK.png with size 43x726
# Deleting unusually small image: data/without_signal/12880357_SSTV.png with size 20x1420
# Deleting unusually small image: data/without_signal/12945022_GMSK.png with size 4x1480
# Deleting unusually small image: data/without_signal/12911816_FM.png with size 1x1534
# Deleting unusually small image: data/without_signal/12914573_GFSK.png with size 6x1538
# Deleting unusually small image: data/without_signal/12824503_FM.png with size 1x1433
# Deleting unusually small image: data/without_signal/12971330_FSK.png with size 1x1486
# Deleting unusually small image: data/without_signal/12919559_FSK AX.25 G3RUH.png with size 1x1529
# Deleting unusually small image: data/without_signal/12945711_GMSK.png with size 3x1530
# Deleting unusually small image: data/without_signal/12847477_GFSK.png with size 2x1534
# Deleting unusually small image: data/without_signal/12926155_FSK AX.100 Mode 5.png with size 1x1382
# Deleting unusually small image: data/without_signal/12910354_LoRa.png with size 19x1544
# Deleting unusually small image: data/without_signal/12788478_SSTV.png with size 1x1533
# Deleting unusually small image: data/without_signal/12998018_FM.png with size 1x1505
# Deleting unusually small image: data/without_signal/12933363_GMSK.png with size 1x1517
# Deleting unusually small image: data/without_signal/12809664_FSK.png with size 1x1398
# Deleting unusually small image: data/without_signal/12993828_GMSK.png with size 2x1521
# Deleting unusually small image: data/without_signal/12960759_BPSK.png with size 1x1513
# Deleting unusually small image: data/without_signal/12813762_FM.png with size 617x1020
# Deleting unusually small image: data/without_signal/13007418_LoRa.png with size 2x1521
# Deleting unusually small image: data/without_signal/12773316_GMSK.png with size 9x1537
# Deleting unusually small image: data/without_signal/12848682_BPSK.png with size 2x1510
# Deleting unusually small image: data/without_signal/12833709_FSK AX.100 Mode 5.png with size 6x1544
# Deleting unusually small image: data/without_signal/12773288_BPSK.png with size 1x1534
# Deleting unusually small image: data/without_signal/12793428_CW.png with size 3x1495
# Deleting unusually small image: data/without_signal/12970103_BPSK.png with size 3x1520
# Deleting unusually small image: data/without_signal/12806078_FSK AX.100 Mode 5.png with size 4x1510
# Deleting unusually small image: data/without_signal/12963132_CW.png with size 32x1489
# Deleting unusually small image: data/without_signal/12927497_GFSK.png with size 20x1537
# Deleting unusually small image: data/without_signal/12777144_GFSK.png with size 2x1521
# Deleting unusually small image: data/without_signal/12921807_CW.png with size 7x980
# Deleting unusually small image: data/without_signal/12865534_GMSK.png with size 2x1529
# Deleting unusually small image: data/without_signal/12934838_BPSK.png with size 1x1518
# Deleting unusually small image: data/without_signal/12797826_FSK.png with size 2x1535
# Deleting unusually small image: data/without_signal/12778599_FSK.png with size 3x1537
# Deleting unusually small image: data/without_signal/12848683_FM.png with size 2x1531
# Deleting unusually small image: data/without_signal/12785513_CW.png with size 4x1387
# Deleting unusually small image: data/without_signal/12885248_BPSK.png with size 2x1522
# Deleting unusually small image: data/without_signal/12802892_BPSK.png with size 5x1502
# Deleting unusually small image: data/without_signal/12922172_CW.png with size 1x1465
# Deleting unusually small image: data/without_signal/12935599_GMSK.png with size 63x1544
# Deleting unusually small image: data/without_signal/12856800_FSK.png with size 4x1544
# Deleting unusually small image: data/without_signal/12962849_FSK.png with size 1x1481
# Cleaned up without-signal images.
